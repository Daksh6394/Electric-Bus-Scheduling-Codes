# %%
# E = cleaned_E
from docplex.mp.model import Model
from datetime import timedelta

# --- CONSTANTS ---
HOURS = 24
MINUTES_IN_DAY = 1440
MinUtilTime = 150
MinUtilTime_2 = 150
MaxUtilTime = 1000

vehicle_fixed_cost = 1000
freq_penalty = 1000

nvehicle = 150
K = range(nvehicle)
H = range(HOURS)

bigM = 1440

# freq1 = [0]*17 + [3, 4, 5, 5, 6, 0, 0]  # ATB
# freq2 = [0]*17 + [3, 4, 5, 5, 6, 0, 0]  # HSK
freq1 = [0, 0, 0, 0, 4, 4, 2, 2, 2, 2, 4, 2, 2, 2, 1, 0, 2, 1, 2, 1, 2, 1, 0, 0]
freq2 = [0, 0, 0, 0, 4, 4, 2, 2, 2, 2, 4, 2, 2, 2, 1, 0, 2, 1, 2, 2, 2, 1, 0, 0]

arc_data = {
    ("X", "X"): (0, 150),
    ("X", "HSK"): (10, 150),
    ("X", "ATB"): (40, 150),
    ("HSK", "HSK"): (200, 150),
    ("ATB", "ATB"): (200, 150),
    ("HSK", "ATB"): (110, 1),
    ("ATB", "HSK"): (110, 1),
    ("HSK", "X"): (10, 150),
    ("ATB", "X"): (40, 150)
}

transitions = {"ATB": "HSK", "HSK": "ATB"}
travel_time = {("ATB", "HSK"): 110, ("HSK", "ATB"): 110}

# --- NODES ---
nodes = []
node_id = 1
nodes.append({'id': node_id, 'time': 0, 'loc': 'X'})
start_node_id = node_id
node_id += 1

for hour in H:
    for i in range(freq1[hour]):
        time_val = hour * 60 + (i * 60 // max(freq1[hour], 1))
        nodes.append({'id': node_id, 'time': time_val, 'loc': 'ATB'})
        node_id += 1
    for i in range(freq2[hour]):
        time_val = hour * 60 + (i * 60 // max(freq2[hour], 1))
        nodes.append({'id': node_id, 'time': time_val, 'loc': 'HSK'})
        node_id += 1

nodes.append({'id': node_id, 'time': MINUTES_IN_DAY, 'loc': 'X'})
end_node_id = node_id
node_id += 1

nodes.sort(key=lambda x: x['time'])
V = nodes.copy()

# --- INITIAL ARCS ---
E = []
synthetic_id = node_id
synthetic_nodes = []

for node in nodes:
    loc = node['loc']
    dst_time = node['time']
    if loc in ['ATB', 'HSK']:
        cost, N_bus = arc_data[('X', loc)]
        if dst_time >= cost:
            E.append({
                'src': {'id': start_node_id, 'time': 0, 'loc': 'X'},
                'dst': {'id': node['id'], 'time': dst_time, 'loc': loc},
                'cost': cost,
                'N_bus': N_bus
            })

for node in nodes:
    loc = node['loc']
    time = node['time']
    src_id = node['id']

    if loc not in transitions:
        continue

    total_time = 0
    curr_loc = loc
    curr_time = time
    curr_src_id = src_id

    while total_time + travel_time[(curr_loc, transitions[curr_loc])] <= MinUtilTime_2:
        next_loc = transitions[curr_loc]
        cost = travel_time[(curr_loc, next_loc)]
        next_time = curr_time + cost

        if next_time > MINUTES_IN_DAY:
            break

        dst = {'id': synthetic_id, 'time': next_time, 'loc': next_loc}
        synthetic_nodes.append(dst)

        E.append({
            'src': {'id': curr_src_id, 'time': curr_time, 'loc': curr_loc},
            'dst': dst,
            'cost': cost,
            'N_bus': 1
        })

        curr_src_id = synthetic_id
        curr_time = next_time
        curr_loc = next_loc
        synthetic_id += 1
        total_time += cost

    if curr_time <= MINUTES_IN_DAY:
        cost_to_X, N_bus_to_X = arc_data[(curr_loc, 'X')]
        E.append({
            'src': {'id': curr_src_id, 'time': curr_time, 'loc': curr_loc},
            'dst': {'id': end_node_id, 'time': MINUTES_IN_DAY, 'loc': 'X'},
            'cost': cost_to_X,
            'N_bus': N_bus_to_X
        })

V.extend(synthetic_nodes)

for node in V:
    node['hhmm'] = str(timedelta(minutes=node['time']))[:-3]

# --- ADD WAITING AND DEADHEADING ARCS ---
MAX_WAIT = 60
augmented_E = E.copy()
unique_keys = set()

# Add existing arcs to unique_keys to avoid duplication later
for e in E:
    arc_key = (
        e['src']['id'], e['src']['time'], e['src']['loc'],
        e['dst']['id'], e['dst']['time'], e['dst']['loc'],
        e['cost'], e['N_bus']
    )
    unique_keys.add(arc_key)

# # Waiting arcs
# for src in V:
#     for dst in V:
#         if src['id'] == dst['id']:
#             continue
#         time_diff = dst['time'] - src['time']
#         if src['loc'] == dst['loc'] and 0 < time_diff <= MAX_WAIT:
#             arc_key = (
#                 src['id'], src['time'], src['loc'],
#                 dst['id'], dst['time'], dst['loc'],
#                 200, 150
#             )
#             if arc_key not in unique_keys:
#                 unique_keys.add(arc_key)
#                 augmented_E.append({
#                     'src': src,
#                     'dst': dst,
#                     'cost': 200,
#                     'N_bus': 150
#                 })
# Sort nodes by location and time to easily find next closest at same loc
from collections import defaultdict

# Group nodes by location
nodes_by_loc = defaultdict(list)
for node in V:
    nodes_by_loc[node['loc']].append(node)

# Sort nodes by time for each location
for loc in nodes_by_loc:
    nodes_by_loc[loc].sort(key=lambda n: n['time'])

# Create minimal waiting arcs (only to immediate next time at same loc)
for loc, nodes in nodes_by_loc.items():
    for i in range(len(nodes) - 1):
        src = nodes[i]
        dst = nodes[i + 1]

        time_diff = dst['time'] - src['time']
        if 0 < time_diff <= MAX_WAIT:
            arc_key = (
                src['id'], src['time'], src['loc'],
                dst['id'], dst['time'], dst['loc'],
                200, 150
            )
            if arc_key not in unique_keys:
                unique_keys.add(arc_key)
                augmented_E.append({
                    'src': src,
                    'dst': dst,
                    'cost': 200,
                    'N_bus': 150
                })


# Deadheading arcs
# for src in V:
#     for dst in V:
#         if src['id'] == dst['id'] or src['loc'] == dst['loc']:
#             continue

#         key = (src['loc'], dst['loc'])
#         if key not in arc_data:
#             continue

#         travel_t, cap = arc_data[key]
#         if dst['time'] > src['time'] + travel_t:
#             arc_key = (
#                 src['id'], src['time'], src['loc'],
#                 dst['id'], dst['time'], dst['loc'],
#                 travel_t, cap
#             )
#             if arc_key not in unique_keys:
#                 unique_keys.add(arc_key)
#                 augmented_E.append({
#                     'src': src,
#                     'dst': dst,
#                     'cost': 220,
#                     'N_bus': 150
#                 })
# for src in V:
#     best_arcs_by_dst_loc = {}
    
#     for dst in V:
#         if src['id'] == dst['id'] or src['loc'] == dst['loc']:
#             continue

#         key = (src['loc'], dst['loc'])
#         if key not in arc_data:
#             continue

#         travel_t, cap = arc_data[key]

#         if dst['time'] > src['time'] + travel_t:
#             time_diff = dst['time'] - src['time'] - travel_t

#             # Keep only the best arc (least time diff) per dst location
#             if dst['loc'] not in best_arcs_by_dst_loc or time_diff < best_arcs_by_dst_loc[dst['loc']]['time_diff']:
#                 best_arcs_by_dst_loc[dst['loc']] = {
#                     'dst': dst,
#                     'travel_t': travel_t,
#                     'cap': cap,
#                     'time_diff': time_diff
#                 }

#     # Now select the single best arc among all dst_locs (least time_diff)
#     if best_arcs_by_dst_loc:
#         # Find arc with minimal time_diff overall
#         best_dst_loc = min(best_arcs_by_dst_loc, key=lambda loc: best_arcs_by_dst_loc[loc]['time_diff'])
#         best = best_arcs_by_dst_loc[best_dst_loc]

#         arc_key = (
#             src['id'], src['time'], src['loc'],
#             best['dst']['id'], best['dst']['time'], best['dst']['loc'],
#             best['travel_t'], best['cap']
#         )

#         if arc_key not in unique_keys:
#             unique_keys.add(arc_key)
#             augmented_E.append({
#                 'src': src,
#                 'dst': best['dst'],
#                 'cost': 220,
#                 'N_bus': 150
#             })


# Final cleaned arcs
E = augmented_E

# --- FINAL OUTPUT [unchanged] ---
for arc in E:
    print({
        'src_id': arc['src']['id'],
        'src_loc': arc['src']['loc'],
        'src_time': arc['src']['time'],
        'dst_id': arc['dst']['id'],
        'dst_loc': arc['dst']['loc'],
        'dst_time': arc['dst']['time'],
        'cost': arc['cost'],
        'N_bus': arc['N_bus']
    })
# --- MODEL ---
mdl = Model("VehicleScheduling")
mdl.context.cplex_parameters.lpmethod = 3

x = mdl.binary_var_dict(((e['src']['id'], e['dst']['id'], k) for e in E for k in K), name='x')
z = mdl.binary_var_dict(K, name='z')
T = mdl.continuous_var_dict(K, name='T', lb=0)

node_ids_in_arcs = set()
for e in E:
    node_ids_in_arcs.add(e['src']['id'])
    node_ids_in_arcs.add(e['dst']['id'])

arrival_time = mdl.continuous_var_dict(((k, nid) for k in K for nid in node_ids_in_arcs), name='arr', lb=0, ub=MINUTES_IN_DAY)
freq_slack_ATB = mdl.continuous_var_dict(H, name='freq_slack_ATB', lb=0)
freq_slack_HSK = mdl.continuous_var_dict(H, name='freq_slack_HSK', lb=0)

mdl.minimize(
    mdl.sum(e['cost'] * x[e['src']['id'], e['dst']['id'], k] for e in E for k in K) +
    mdl.sum(vehicle_fixed_cost * z[k] for k in K) 
)

# mdl.minimize(
#     mdl.sum(z[k] for k in K) 
# )
#     # mdl.sum(freq_penalty * (freq_slack_ATB[h] + freq_slack_HSK[h]) for h in H)

for k in K:
    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E) <= bigM * z[k])
    mdl.add_constraint(z[k] <= mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E))

    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['src']['id'] == start_node_id) == z[k])
    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['dst']['id'] == end_node_id) == z[k])

    for node in V:
        i = node['id']
        if i != start_node_id and i != end_node_id:
            mdl.add_constraint(
                mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['src']['id'] == i) ==
                mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['dst']['id'] == i)
            )

for e in E:
    if e['N_bus'] == 1:
        mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for k in K) <= 1)

for k in K:
    mdl.add_constraint(T[k] == mdl.sum(e['cost'] * x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['N_bus'] == 1))
    mdl.add_constraint(T[k] >= MinUtilTime * z[k])
    mdl.add_constraint(T[k] <= MaxUtilTime * z[k])

for e in E:
    for k in K:
        i, j = e['src']['id'], e['dst']['id']
        cost = e['cost']
        mdl.add_constraint(arrival_time[k, j] >= arrival_time[k, i] + cost - bigM * (1 - x.get((i, j, k), 0)))
        mdl.add_constraint(arrival_time[k, j] <= arrival_time[k, i] + cost + bigM * (1 - x.get((i, j, k), 0)))

# for h in H:
#     mdl.add_constraint(
#         mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0)
#                 for k in K
#                 for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'ATB' and (e['src']['time'] // 60) == h)
#         + freq_slack_ATB[h] >= freq1[h]
#     )
#     mdl.add_constraint(
#         mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0)
#                 for k in K
#                 for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'HSK' and (e['src']['time'] // 60) == h)
#         + freq_slack_HSK[h] >= freq2[h]
#     )
for h in H:
    mdl.add_constraint(
        mdl.sum(
            x[e['src']['id'], e['dst']['id'], k]
            for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'ATB' and (e['src']['time'] // 60) == h
            for k in K
        ) >= freq1[h]
    )
    mdl.add_constraint(
        mdl.sum(
            x[e['src']['id'], e['dst']['id'], k]
            for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'HSK' and (e['src']['time'] // 60) == h
            for k in K
        ) >= freq2[h]
    )
solution = mdl.solve(log_output=True)

if solution:
    print("Objective:", solution.objective_value)
    used_vehicles = [k for k in K if z[k].solution_value > 0.5]
    print(f"Number of vehicles used: {len(used_vehicles)}\n")

    for k in used_vehicles:
        print(f"Schedule for Vehicle {k + 1}: Utilization time = {T[k].solution_value:.2f}")
        current_node = start_node_id
        while current_node != end_node_id:
            next_arcs = [e for e in E if e['src']['id'] == current_node and x.get((e['src']['id'], e['dst']['id'], k), 0).solution_value > 0.5]
            if not next_arcs:
                print("  ERROR: Route incomplete or disconnected.")
                break
            arc = next_arcs[0]
            src, dst = arc['src'], arc['dst']
            src_h, src_m = divmod(int(src['time']), 60)
            dst_h, dst_m = divmod(int(dst['time']), 60)
            print(f"  ({src['loc']} at {src_h:02d}:{src_m:02d}) --> ({dst['loc']} at {dst_h:02d}:{dst_m:02d}), cost={arc['cost']}")
            current_node = dst['id']
        print()
else:
    print("No feasible solution found.")

# %%
# E = cleaned_E
from docplex.mp.model import Model
from datetime import timedelta

# --- CONSTANTS ---
HOURS = 24
MINUTES_IN_DAY = 1440
MinUtilTime = 150
MinUtilTime_2 = 150
MaxUtilTime = 1000

vehicle_fixed_cost = 1000
freq_penalty = 1000

nvehicle = 150
K = range(nvehicle)
H = range(HOURS)

bigM = 1440

# freq1 = [0]*17 + [3, 4, 5, 5, 6, 0, 0]  # ATB
# freq2 = [0]*17 + [3, 4, 5, 5, 6, 0, 0]  # HSK
freq1 = [0, 0, 0, 0, 4, 4, 2, 2, 2, 2, 4, 2, 2, 2, 1, 0, 2, 1, 2, 1, 2, 1, 0, 0]
freq2 = [0, 0, 0, 0, 4, 4, 2, 2, 2, 2, 4, 2, 2, 2, 1, 0, 2, 1, 2, 2, 2, 1, 0, 0]

arc_data = {
    ("X", "X"): (0, 150),
    ("X", "HSK"): (10, 150),
    ("X", "ATB"): (40, 150),
    ("HSK", "HSK"): (200, 150),
    ("ATB", "ATB"): (200, 150),
    ("HSK", "ATB"): (110, 1),
    ("ATB", "HSK"): (110, 1),
    ("HSK", "X"): (10, 150),
    ("ATB", "X"): (40, 150)
}

transitions = {"ATB": "HSK", "HSK": "ATB"}
travel_time = {("ATB", "HSK"): 110, ("HSK", "ATB"): 110}

# --- NODES ---
nodes = []
node_id = 1
nodes.append({'id': node_id, 'time': 0, 'loc': 'X'})
start_node_id = node_id
node_id += 1

for hour in H:
    for i in range(freq1[hour]):
        time_val = hour * 60 + (i * 60 // max(freq1[hour], 1))
        nodes.append({'id': node_id, 'time': time_val, 'loc': 'ATB'})
        node_id += 1
    for i in range(freq2[hour]):
        time_val = hour * 60 + (i * 60 // max(freq2[hour], 1))
        nodes.append({'id': node_id, 'time': time_val, 'loc': 'HSK'})
        node_id += 1

nodes.append({'id': node_id, 'time': MINUTES_IN_DAY, 'loc': 'X'})
end_node_id = node_id
node_id += 1

nodes.sort(key=lambda x: x['time'])
V = nodes.copy()

# --- INITIAL ARCS ---
E = []
synthetic_id = node_id
synthetic_nodes = []

for node in nodes:
    loc = node['loc']
    dst_time = node['time']
    if loc in ['ATB', 'HSK']:
        cost, N_bus = arc_data[('X', loc)]
        if dst_time >= cost:
            E.append({
                'src': {'id': start_node_id, 'time': 0, 'loc': 'X'},
                'dst': {'id': node['id'], 'time': dst_time, 'loc': loc},
                'cost': cost,
                'N_bus': N_bus
            })

for node in nodes:
    loc = node['loc']
    time = node['time']
    src_id = node['id']

    if loc not in transitions:
        continue

    total_time = 0
    curr_loc = loc
    curr_time = time
    curr_src_id = src_id

    while total_time + travel_time[(curr_loc, transitions[curr_loc])] <= MinUtilTime_2:
        next_loc = transitions[curr_loc]
        cost = travel_time[(curr_loc, next_loc)]
        next_time = curr_time + cost

        if next_time > MINUTES_IN_DAY:
            break

        dst = {'id': synthetic_id, 'time': next_time, 'loc': next_loc}
        synthetic_nodes.append(dst)

        E.append({
            'src': {'id': curr_src_id, 'time': curr_time, 'loc': curr_loc},
            'dst': dst,
            'cost': cost,
            'N_bus': 1
        })

        curr_src_id = synthetic_id
        curr_time = next_time
        curr_loc = next_loc
        synthetic_id += 1
        total_time += cost

    if curr_time <= MINUTES_IN_DAY:
        cost_to_X, N_bus_to_X = arc_data[(curr_loc, 'X')]
        E.append({
            'src': {'id': curr_src_id, 'time': curr_time, 'loc': curr_loc},
            'dst': {'id': end_node_id, 'time': MINUTES_IN_DAY, 'loc': 'X'},
            'cost': cost_to_X,
            'N_bus': N_bus_to_X
        })

V.extend(synthetic_nodes)

for node in V:
    node['hhmm'] = str(timedelta(minutes=node['time']))[:-3]

# --- ADD WAITING AND DEADHEADING ARCS ---
MAX_WAIT = 60
augmented_E = E.copy()
unique_keys = set()

# Add existing arcs to unique_keys to avoid duplication later
for e in E:
    arc_key = (
        e['src']['id'], e['src']['time'], e['src']['loc'],
        e['dst']['id'], e['dst']['time'], e['dst']['loc'],
        e['cost'], e['N_bus']
    )
    unique_keys.add(arc_key)

# # Waiting arcs
# for src in V:
#     for dst in V:
#         if src['id'] == dst['id']:
#             continue
#         time_diff = dst['time'] - src['time']
#         if src['loc'] == dst['loc'] and 0 < time_diff <= MAX_WAIT:
#             arc_key = (
#                 src['id'], src['time'], src['loc'],
#                 dst['id'], dst['time'], dst['loc'],
#                 200, 150
#             )
#             if arc_key not in unique_keys:
#                 unique_keys.add(arc_key)
#                 augmented_E.append({
#                     'src': src,
#                     'dst': dst,
#                     'cost': 200,
#                     'N_bus': 150
#                 })
# Sort nodes by location and time to easily find next closest at same loc
from collections import defaultdict

# Group nodes by location
nodes_by_loc = defaultdict(list)
for node in V:
    nodes_by_loc[node['loc']].append(node)

# Sort nodes by time for each location
for loc in nodes_by_loc:
    nodes_by_loc[loc].sort(key=lambda n: n['time'])

# Create minimal waiting arcs (only to immediate next time at same loc)
for loc, nodes in nodes_by_loc.items():
    for i in range(len(nodes) - 1):
        src = nodes[i]
        dst = nodes[i + 1]

        time_diff = dst['time'] - src['time']
        if 0 < time_diff <= MAX_WAIT:
            arc_key = (
                src['id'], src['time'], src['loc'],
                dst['id'], dst['time'], dst['loc'],
                200, 150
            )
            if arc_key not in unique_keys:
                unique_keys.add(arc_key)
                augmented_E.append({
                    'src': src,
                    'dst': dst,
                    'cost': 200,
                    'N_bus': 150
                })


# Deadheading arcs
# for src in V:
#     for dst in V:
#         if src['id'] == dst['id'] or src['loc'] == dst['loc']:
#             continue

#         key = (src['loc'], dst['loc'])
#         if key not in arc_data:
#             continue

#         travel_t, cap = arc_data[key]
#         if dst['time'] > src['time'] + travel_t:
#             arc_key = (
#                 src['id'], src['time'], src['loc'],
#                 dst['id'], dst['time'], dst['loc'],
#                 travel_t, cap
#             )
#             if arc_key not in unique_keys:
#                 unique_keys.add(arc_key)
#                 augmented_E.append({
#                     'src': src,
#                     'dst': dst,
#                     'cost': 220,
#                     'N_bus': 150
#                 })
# for src in V:
#     best_arcs_by_dst_loc = {}
    
#     for dst in V:
#         if src['id'] == dst['id'] or src['loc'] == dst['loc']:
#             continue

#         key = (src['loc'], dst['loc'])
#         if key not in arc_data:
#             continue

#         travel_t, cap = arc_data[key]

#         if dst['time'] > src['time'] + travel_t:
#             time_diff = dst['time'] - src['time'] - travel_t

#             # Keep only the best arc (least time diff) per dst location
#             if dst['loc'] not in best_arcs_by_dst_loc or time_diff < best_arcs_by_dst_loc[dst['loc']]['time_diff']:
#                 best_arcs_by_dst_loc[dst['loc']] = {
#                     'dst': dst,
#                     'travel_t': travel_t,
#                     'cap': cap,
#                     'time_diff': time_diff
#                 }

#     # Now select the single best arc among all dst_locs (least time_diff)
#     if best_arcs_by_dst_loc:
#         # Find arc with minimal time_diff overall
#         best_dst_loc = min(best_arcs_by_dst_loc, key=lambda loc: best_arcs_by_dst_loc[loc]['time_diff'])
#         best = best_arcs_by_dst_loc[best_dst_loc]

#         arc_key = (
#             src['id'], src['time'], src['loc'],
#             best['dst']['id'], best['dst']['time'], best['dst']['loc'],
#             best['travel_t'], best['cap']
#         )

#         if arc_key not in unique_keys:
#             unique_keys.add(arc_key)
#             augmented_E.append({
#                 'src': src,
#                 'dst': best['dst'],
#                 'cost': 220,
#                 'N_bus': 150
#             })


# Final cleaned arcs
E = augmented_E
print(E)

# --- FINAL OUTPUT [unchanged] ---
for arc in E:
    print({
        'src_id': arc['src']['id'],
        'src_loc': arc['src']['loc'],
        'src_time': arc['src']['time'],
        'dst_id': arc['dst']['id'],
        'dst_loc': arc['dst']['loc'],
        'dst_time': arc['dst']['time'],
        'cost': arc['cost'],
        'N_bus': arc['N_bus']
    })
# --- MODEL ---
mdl = Model("VehicleScheduling")
mdl.context.cplex_parameters.lpmethod = 3

x = mdl.binary_var_dict(((e['src']['id'], e['dst']['id'], k) for e in E for k in K), name='x')
z = mdl.binary_var_dict(K, name='z')
T = mdl.continuous_var_dict(K, name='T', lb=0)

node_ids_in_arcs = set()
for e in E:
    node_ids_in_arcs.add(e['src']['id'])
    node_ids_in_arcs.add(e['dst']['id'])

arrival_time = mdl.continuous_var_dict(((k, nid) for k in K for nid in node_ids_in_arcs), name='arr', lb=0, ub=MINUTES_IN_DAY)
freq_slack_ATB = mdl.continuous_var_dict(H, name='freq_slack_ATB', lb=0)
freq_slack_HSK = mdl.continuous_var_dict(H, name='freq_slack_HSK', lb=0)

mdl.minimize(
    mdl.sum(e['cost'] * x[e['src']['id'], e['dst']['id'], k] for e in E for k in K) +
    mdl.sum(vehicle_fixed_cost * z[k] for k in K) 
)

# mdl.minimize(
#     mdl.sum(z[k] for k in K) 
# )
#     # mdl.sum(freq_penalty * (freq_slack_ATB[h] + freq_slack_HSK[h]) for h in H)

for k in K:
    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E) <= bigM * z[k])
    mdl.add_constraint(z[k] <= mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E))

    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['src']['id'] == start_node_id) == z[k])
    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['dst']['id'] == end_node_id) == z[k])

    for node in V:
        i = node['id']
        if i != start_node_id and i != end_node_id:
            mdl.add_constraint(
                mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['src']['id'] == i) ==
                mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['dst']['id'] == i)
            )

for e in E:
    if e['N_bus'] == 1:
        mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for k in K) <= 1)

for k in K:
    mdl.add_constraint(T[k] == mdl.sum(e['cost'] * x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['N_bus'] == 1))
    mdl.add_constraint(T[k] >= MinUtilTime * z[k])
    mdl.add_constraint(T[k] <= MaxUtilTime * z[k])

for e in E:
    for k in K:
        i, j = e['src']['id'], e['dst']['id']
        cost = e['cost']
        mdl.add_constraint(arrival_time[k, j] >= arrival_time[k, i] + cost - bigM * (1 - x.get((i, j, k), 0)))
        mdl.add_constraint(arrival_time[k, j] <= arrival_time[k, i] + cost + bigM * (1 - x.get((i, j, k), 0)))

# for h in H:
#     mdl.add_constraint(
#         mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0)
#                 for k in K
#                 for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'ATB' and (e['src']['time'] // 60) == h)
#         + freq_slack_ATB[h] >= freq1[h]
#     )
#     mdl.add_constraint(
#         mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0)
#                 for k in K
#                 for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'HSK' and (e['src']['time'] // 60) == h)
#         + freq_slack_HSK[h] >= freq2[h]
#     )
for h in H:
    mdl.add_constraint(
        mdl.sum(
            x[e['src']['id'], e['dst']['id'], k]
            for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'ATB' and (e['src']['time'] // 60) == h
            for k in K
        ) >= freq1[h]
    )
    mdl.add_constraint(
        mdl.sum(
            x[e['src']['id'], e['dst']['id'], k]
            for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'HSK' and (e['src']['time'] // 60) == h
            for k in K
        ) >= freq2[h]
    )
solution = mdl.solve(log_output=True)

if solution:
    print("Objective:", solution.objective_value)
    used_vehicles = [k for k in K if z[k].solution_value > 0.5]
    print(f"Number of vehicles used: {len(used_vehicles)}\n")

    for k in used_vehicles:
        print(f"Schedule for Vehicle {k + 1}: Utilization time = {T[k].solution_value:.2f}")
        current_node = start_node_id
        while current_node != end_node_id:
            next_arcs = [e for e in E if e['src']['id'] == current_node and x.get((e['src']['id'], e['dst']['id'], k), 0).solution_value > 0.5]
            if not next_arcs:
                print("  ERROR: Route incomplete or disconnected.")
                break
            arc = next_arcs[0]
            src, dst = arc['src'], arc['dst']
            src_h, src_m = divmod(int(src['time']), 60)
            dst_h, dst_m = divmod(int(dst['time']), 60)
            print(f"  ({src['loc']} at {src_h:02d}:{src_m:02d}) --> ({dst['loc']} at {dst_h:02d}:{dst_m:02d}), cost={arc['cost']}")
            current_node = dst['id']
        print()
else:
    print("No feasible solution found.")
# Out:
# [{'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 2, 'time': 240, 'loc': 'ATB'}, 'cost': 40, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 6, 'time': 240, 'loc': 'HSK'}, 'cost': 10, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 3, 'time': 255, 'loc': 'ATB'}, 'cost': 40, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 7, 'time': 255, 'loc': 'HSK'}, 'cost': 10, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 4, 'time': 270, 'loc': 'ATB'}, 'cost': 40, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 8, 'time': 270, 'loc': 'HSK'}, 'cost': 10, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 5, 'time': 285, 'loc': 'ATB'}, 'cost': 40, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 9, 'time': 285, 'loc': 'HSK'}, 'cost': 10, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 10, 'time': 300, 'loc': 'ATB'}, 'cost': 40, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 14, 'time': 300, 'loc': 'HSK'}, 'cost': 10, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 11, 'time': 315, 'loc': 'ATB'}, 'cost': 40, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 15, 'time': 315, 'loc': 'HSK'}, 'cost': 10, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 12, 'time': 330, 'loc': 'ATB'}, 'cost': 40, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 16, 'time': 330, 'loc': 'HSK'}, 'cost': 10, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 13, 'time': 345, 'loc': 'ATB'}, 'cost': 40, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 17, 'time': 345, 'loc': 'HSK'}, 'cost': 10, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 18, 'time': 360, 'loc': 'ATB'}, 'cost': 40, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 20, 'time': 360, 'loc': 'HSK'}, 'cost': 10, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 19, 'time': 390, 'loc': 'ATB'}, 'cost': 40, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id': 21, 'time': 390, 'loc': 'HSK'}, 'cost': 10, 'N_bus': 150}, {'src': {'id': 1, 'time': 0, 'loc': 'X'}, 'dst': {'id':
 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 8, 'src_loc': 'HSK', 'src_time': 270, 'dst_id': 81, 'dst_loc': 'ATB', 'dst_time': 380, 'cost': 110, 'N_bus': 1}
# {'src_id': 81, 'src_loc': 'ATB', 'src_time': 380, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 5, 'src_loc': 'ATB', 'src_time': 285, 'dst_id': 82, 'dst_loc': 'HSK', 'dst_time': 395, 'cost': 110, 'N_bus': 1}
# {'src_id': 82, 'src_loc': 'HSK', 'src_time': 395, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 9, 'src_loc': 'HSK', 'src_time': 285, 'dst_id': 83, 'dst_loc': 'ATB', 'dst_time': 395, 'cost': 110, 'N_bus': 1}
# {'src_id': 83, 'src_loc': 'ATB', 'src_time': 395, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 10, 'src_loc': 'ATB', 'src_time': 300, 'dst_id': 84, 'dst_loc': 'HSK', 'dst_time': 410, 'cost': 110, 'N_bus': 1}
# {'src_id': 84, 'src_loc': 'HSK', 'src_time': 410, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 14, 'src_loc': 'HSK', 'src_time': 300, 'dst_id': 85, 'dst_loc': 'ATB', 'dst_time': 410, 'cost': 110, 'N_bus': 1}
# {'src_id': 85, 'src_loc': 'ATB', 'src_time': 410, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 11, 'src_loc': 'ATB', 'src_time': 315, 'dst_id': 86, 'dst_loc': 'HSK', 'dst_time': 425, 'cost': 110, 'N_bus': 1}
# {'src_id': 86, 'src_loc': 'HSK', 'src_time': 425, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 15, 'src_loc': 'HSK', 'src_time': 315, 'dst_id': 87, 'dst_loc': 'ATB', 'dst_time': 425, 'cost': 110, 'N_bus': 1}
# {'src_id': 87, 'src_loc': 'ATB', 'src_time': 425, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 12, 'src_loc': 'ATB', 'src_time': 330, 'dst_id': 88, 'dst_loc': 'HSK', 'dst_time': 440, 'cost': 110, 'N_bus': 1}
# {'src_id': 88, 'src_loc': 'HSK', 'src_time': 440, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 16, 'src_loc': 'HSK', 'src_time': 330, 'dst_id': 89, 'dst_loc': 'ATB', 'dst_time': 440, 'cost': 110, 'N_bus': 1}
# {'src_id': 89, 'src_loc': 'ATB', 'src_time': 440, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 13, 'src_loc': 'ATB', 'src_time': 345, 'dst_id': 90, 'dst_loc': 'HSK', 'dst_time': 455, 'cost': 110, 'N_bus': 1}
# {'src_id': 90, 'src_loc': 'HSK', 'src_time': 455, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 17, 'src_loc': 'HSK', 'src_time': 345, 'dst_id': 91, 'dst_loc': 'ATB', 'dst_time': 455, 'cost': 110, 'N_bus': 1}
# {'src_id': 91, 'src_loc': 'ATB', 'src_time': 455, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 18, 'src_loc': 'ATB', 'src_time': 360, 'dst_id': 92, 'dst_loc': 'HSK', 'dst_time': 470, 'cost': 110, 'N_bus': 1}
# {'src_id': 92, 'src_loc': 'HSK', 'src_time': 470, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 20, 'src_loc': 'HSK', 'src_time': 360, 'dst_id': 93, 'dst_loc': 'ATB', 'dst_time': 470, 'cost': 110, 'N_bus': 1}
# {'src_id': 93, 'src_loc': 'ATB', 'src_time': 470, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 19, 'src_loc': 'ATB', 'src_time': 390, 'dst_id': 94, 'dst_loc': 'HSK', 'dst_time': 500, 'cost': 110, 'N_bus': 1}
# {'src_id': 94, 'src_loc': 'HSK', 'src_time': 500, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 21, 'src_loc': 'HSK', 'src_time': 390, 'dst_id': 95, 'dst_loc': 'ATB', 'dst_time': 500, 'cost': 110, 'N_bus': 1}
# {'src_id': 95, 'src_loc': 'ATB', 'src_time': 500, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 22, 'src_loc': 'ATB', 'src_time': 420, 'dst_id': 96, 'dst_loc': 'HSK', 'dst_time': 530, 'cost': 110, 'N_bus': 1}
# {'src_id': 96, 'src_loc': 'HSK', 'src_time': 530, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 24, 'src_loc': 'HSK', 'src_time': 420, 'dst_id': 97, 'dst_loc': 'ATB', 'dst_time': 530, 'cost': 110, 'N_bus': 1}
# {'src_id': 97, 'src_loc': 'ATB', 'src_time': 530, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 23, 'src_loc': 'ATB', 'src_time': 450, 'dst_id': 98, 'dst_loc': 'HSK', 'dst_time': 560, 'cost': 110, 'N_bus': 1}
# {'src_id': 98, 'src_loc': 'HSK', 'src_time': 560, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 25, 'src_loc': 'HSK', 'src_time': 450, 'dst_id': 99, 'dst_loc': 'ATB', 'dst_time': 560, 'cost': 110, 'N_bus': 1}
# {'src_id': 99, 'src_loc': 'ATB', 'src_time': 560, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 26, 'src_loc': 'ATB', 'src_time': 480, 'dst_id': 100, 'dst_loc': 'HSK', 'dst_time': 590, 'cost': 110, 'N_bus': 1}
# {'src_id': 100, 'src_loc': 'HSK', 'src_time': 590, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 28, 'src_loc': 'HSK', 'src_time': 480, 'dst_id': 101, 'dst_loc': 'ATB', 'dst_time': 590, 'cost': 110, 'N_bus': 1}
# {'src_id': 101, 'src_loc': 'ATB', 'src_time': 590, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 27, 'src_loc': 'ATB', 'src_time': 510, 'dst_id': 102, 'dst_loc': 'HSK', 'dst_time': 620, 'cost': 110, 'N_bus': 1}
# {'src_id': 102, 'src_loc': 'HSK', 'src_time': 620, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 29, 'src_loc': 'HSK', 'src_time': 510, 'dst_id': 103, 'dst_loc': 'ATB', 'dst_time': 620, 'cost': 110, 'N_bus': 1}
# {'src_id': 103, 'src_loc': 'ATB', 'src_time': 620, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 30, 'src_loc': 'ATB', 'src_time': 540, 'dst_id': 104, 'dst_loc': 'HSK', 'dst_time': 650, 'cost': 110, 'N_bus': 1}
# {'src_id': 104, 'src_loc': 'HSK', 'src_time': 650, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 32, 'src_loc': 'HSK', 'src_time': 540, 'dst_id': 105, 'dst_loc': 'ATB', 'dst_time': 650, 'cost': 110, 'N_bus': 1}
# {'src_id': 105, 'src_loc': 'ATB', 'src_time': 650, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 31, 'src_loc': 'ATB', 'src_time': 570, 'dst_id': 106, 'dst_loc': 'HSK', 'dst_time': 680, 'cost': 110, 'N_bus': 1}
# {'src_id': 106, 'src_loc': 'HSK', 'src_time': 680, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 33, 'src_loc': 'HSK', 'src_time': 570, 'dst_id': 107, 'dst_loc': 'ATB', 'dst_time': 680, 'cost': 110, 'N_bus': 1}
# {'src_id': 107, 'src_loc': 'ATB', 'src_time': 680, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 34, 'src_loc': 'ATB', 'src_time': 600, 'dst_id': 108, 'dst_loc': 'HSK', 'dst_time': 710, 'cost': 110, 'N_bus': 1}
# {'src_id': 108, 'src_loc': 'HSK', 'src_time': 710, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 38, 'src_loc': 'HSK', 'src_time': 600, 'dst_id': 109, 'dst_loc': 'ATB', 'dst_time': 710, 'cost': 110, 'N_bus': 1}
# {'src_id': 109, 'src_loc': 'ATB', 'src_time': 710, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 35, 'src_loc': 'ATB', 'src_time': 615, 'dst_id': 110, 'dst_loc': 'HSK', 'dst_time': 725, 'cost': 110, 'N_bus': 1}
# {'src_id': 110, 'src_loc': 'HSK', 'src_time': 725, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 39, 'src_loc': 'HSK', 'src_time': 615, 'dst_id': 111, 'dst_loc': 'ATB', 'dst_time': 725, 'cost': 110, 'N_bus': 1}
# {'src_id': 111, 'src_loc': 'ATB', 'src_time': 725, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 36, 'src_loc': 'ATB', 'src_time': 630, 'dst_id': 112, 'dst_loc': 'HSK', 'dst_time': 740, 'cost': 110, 'N_bus': 1}
# {'src_id': 112, 'src_loc': 'HSK', 'src_time': 740, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 40, 'src_loc': 'HSK', 'src_time': 630, 'dst_id': 113, 'dst_loc': 'ATB', 'dst_time': 740, 'cost': 110, 'N_bus': 1}
# {'src_id': 113, 'src_loc': 'ATB', 'src_time': 740, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 37, 'src_loc': 'ATB', 'src_time': 645, 'dst_id': 114, 'dst_loc': 'HSK', 'dst_time': 755, 'cost': 110, 'N_bus': 1}
# {'src_id': 114, 'src_loc': 'HSK', 'src_time': 755, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 41, 'src_loc': 'HSK', 'src_time': 645, 'dst_id': 115, 'dst_loc': 'ATB', 'dst_time': 755, 'cost': 110, 'N_bus': 1}
# {'src_id': 115, 'src_loc': 'ATB', 'src_time': 755, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 42, 'src_loc': 'ATB', 'src_time': 660, 'dst_id': 116, 'dst_loc': 'HSK', 'dst_time': 770, 'cost': 110, 'N_bus': 1}
# {'src_id': 116, 'src_loc': 'HSK', 'src_time': 770, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 44, 'src_loc': 'HSK', 'src_time': 660, 'dst_id': 117, 'dst_loc': 'ATB', 'dst_time': 770, 'cost': 110, 'N_bus': 1}
# {'src_id': 117, 'src_loc': 'ATB', 'src_time': 770, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 43, 'src_loc': 'ATB', 'src_time': 690, 'dst_id': 118, 'dst_loc': 'HSK', 'dst_time': 800, 'cost': 110, 'N_bus': 1}
# {'src_id': 118, 'src_loc': 'HSK', 'src_time': 800, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 45, 'src_loc': 'HSK', 'src_time': 690, 'dst_id': 119, 'dst_loc': 'ATB', 'dst_time': 800, 'cost': 110, 'N_bus': 1}
# {'src_id': 119, 'src_loc': 'ATB', 'src_time': 800, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 46, 'src_loc': 'ATB', 'src_time': 720, 'dst_id': 120, 'dst_loc': 'HSK', 'dst_time': 830, 'cost': 110, 'N_bus': 1}
# {'src_id': 120, 'src_loc': 'HSK', 'src_time': 830, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 48, 'src_loc': 'HSK', 'src_time': 720, 'dst_id': 121, 'dst_loc': 'ATB', 'dst_time': 830, 'cost': 110, 'N_bus': 1}
# {'src_id': 121, 'src_loc': 'ATB', 'src_time': 830, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 47, 'src_loc': 'ATB', 'src_time': 750, 'dst_id': 122, 'dst_loc': 'HSK', 'dst_time': 860, 'cost': 110, 'N_bus': 1}
# {'src_id': 122, 'src_loc': 'HSK', 'src_time': 860, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 49, 'src_loc': 'HSK', 'src_time': 750, 'dst_id': 123, 'dst_loc': 'ATB', 'dst_time': 860, 'cost': 110, 'N_bus': 1}
# {'src_id': 123, 'src_loc': 'ATB', 'src_time': 860, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 50, 'src_loc': 'ATB', 'src_time': 780, 'dst_id': 124, 'dst_loc': 'HSK', 'dst_time': 890, 'cost': 110, 'N_bus': 1}
# {'src_id': 124, 'src_loc': 'HSK', 'src_time': 890, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 52, 'src_loc': 'HSK', 'src_time': 780, 'dst_id': 125, 'dst_loc': 'ATB', 'dst_time': 890, 'cost': 110, 'N_bus': 1}
# {'src_id': 125, 'src_loc': 'ATB', 'src_time': 890, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 51, 'src_loc': 'ATB', 'src_time': 810, 'dst_id': 126, 'dst_loc': 'HSK', 'dst_time': 920, 'cost': 110, 'N_bus': 1}
# {'src_id': 126, 'src_loc': 'HSK', 'src_time': 920, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 53, 'src_loc': 'HSK', 'src_time': 810, 'dst_id': 127, 'dst_loc': 'ATB', 'dst_time': 920, 'cost': 110, 'N_bus': 1}
# {'src_id': 127, 'src_loc': 'ATB', 'src_time': 920, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 54, 'src_loc': 'ATB', 'src_time': 840, 'dst_id': 128, 'dst_loc': 'HSK', 'dst_time': 950, 'cost': 110, 'N_bus': 1}
# {'src_id': 128, 'src_loc': 'HSK', 'src_time': 950, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 55, 'src_loc': 'HSK', 'src_time': 840, 'dst_id': 129, 'dst_loc': 'ATB', 'dst_time': 950, 'cost': 110, 'N_bus': 1}
# {'src_id': 129, 'src_loc': 'ATB', 'src_time': 950, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 56, 'src_loc': 'ATB', 'src_time': 960, 'dst_id': 130, 'dst_loc': 'HSK', 'dst_time': 1070, 'cost': 110, 'N_bus': 1}
# {'src_id': 130, 'src_loc': 'HSK', 'src_time': 1070, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 58, 'src_loc': 'HSK', 'src_time': 960, 'dst_id': 131, 'dst_loc': 'ATB', 'dst_time': 1070, 'cost': 110, 'N_bus': 1}
# {'src_id': 131, 'src_loc': 'ATB', 'src_time': 1070, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 57, 'src_loc': 'ATB', 'src_time': 990, 'dst_id': 132, 'dst_loc': 'HSK', 'dst_time': 1100, 'cost': 110, 'N_bus': 1}
# {'src_id': 132, 'src_loc': 'HSK', 'src_time': 1100, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 59, 'src_loc': 'HSK', 'src_time': 990, 'dst_id': 133, 'dst_loc': 'ATB', 'dst_time': 1100, 'cost': 110, 'N_bus': 1}
# {'src_id': 133, 'src_loc': 'ATB', 'src_time': 1100, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 60, 'src_loc': 'ATB', 'src_time': 1020, 'dst_id': 134, 'dst_loc': 'HSK', 'dst_time': 1130, 'cost': 110, 'N_bus': 1}
# {'src_id': 134, 'src_loc': 'HSK', 'src_time': 1130, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 61, 'src_loc': 'HSK', 'src_time': 1020, 'dst_id': 135, 'dst_loc': 'ATB', 'dst_time': 1130, 'cost': 110, 'N_bus': 1}
# {'src_id': 135, 'src_loc': 'ATB', 'src_time': 1130, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 62, 'src_loc': 'ATB', 'src_time': 1080, 'dst_id': 136, 'dst_loc': 'HSK', 'dst_time': 1190, 'cost': 110, 'N_bus': 1}
# {'src_id': 136, 'src_loc': 'HSK', 'src_time': 1190, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 64, 'src_loc': 'HSK', 'src_time': 1080, 'dst_id': 137, 'dst_loc': 'ATB', 'dst_time': 1190, 'cost': 110, 'N_bus': 1}
# {'src_id': 137, 'src_loc': 'ATB', 'src_time': 1190, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 63, 'src_loc': 'ATB', 'src_time': 1110, 'dst_id': 138, 'dst_loc': 'HSK', 'dst_time': 1220, 'cost': 110, 'N_bus': 1}
# {'src_id': 138, 'src_loc': 'HSK', 'src_time': 1220, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 65, 'src_loc': 'HSK', 'src_time': 1110, 'dst_id': 139, 'dst_loc': 'ATB', 'dst_time': 1220, 'cost': 110, 'N_bus': 1}
# {'src_id': 139, 'src_loc': 'ATB', 'src_time': 1220, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 66, 'src_loc': 'ATB', 'src_time': 1140, 'dst_id': 140, 'dst_loc': 'HSK', 'dst_time': 1250, 'cost': 110, 'N_bus': 1}
# {'src_id': 140, 'src_loc': 'HSK', 'src_time': 1250, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 67, 'src_loc': 'HSK', 'src_time': 1140, 'dst_id': 141, 'dst_loc': 'ATB', 'dst_time': 1250, 'cost': 110, 'N_bus': 1}
# {'src_id': 141, 'src_loc': 'ATB', 'src_time': 1250, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 68, 'src_loc': 'HSK', 'src_time': 1170, 'dst_id': 142, 'dst_loc': 'ATB', 'dst_time': 1280, 'cost': 110, 'N_bus': 1}
# {'src_id': 142, 'src_loc': 'ATB', 'src_time': 1280, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 69, 'src_loc': 'ATB', 'src_time': 1200, 'dst_id': 143, 'dst_loc': 'HSK', 'dst_time': 1310, 'cost': 110, 'N_bus': 1}
# {'src_id': 143, 'src_loc': 'HSK', 'src_time': 1310, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 71, 'src_loc': 'HSK', 'src_time': 1200, 'dst_id': 144, 'dst_loc': 'ATB', 'dst_time': 1310, 'cost': 110, 'N_bus': 1}
# {'src_id': 144, 'src_loc': 'ATB', 'src_time': 1310, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 70, 'src_loc': 'ATB', 'src_time': 1230, 'dst_id': 145, 'dst_loc': 'HSK', 'dst_time': 1340, 'cost': 110, 'N_bus': 1}
# {'src_id': 145, 'src_loc': 'HSK', 'src_time': 1340, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 72, 'src_loc': 'HSK', 'src_time': 1230, 'dst_id': 146, 'dst_loc': 'ATB', 'dst_time': 1340, 'cost': 110, 'N_bus': 1}
# {'src_id': 146, 'src_loc': 'ATB', 'src_time': 1340, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 73, 'src_loc': 'ATB', 'src_time': 1260, 'dst_id': 147, 'dst_loc': 'HSK', 'dst_time': 1370, 'cost': 110, 'N_bus': 1}
# {'src_id': 147, 'src_loc': 'HSK', 'src_time': 1370, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 74, 'src_loc': 'HSK', 'src_time': 1260, 'dst_id': 148, 'dst_loc': 'ATB', 'dst_time': 1370, 'cost': 110, 'N_bus': 1}
# {'src_id': 148, 'src_loc': 'ATB', 'src_time': 1370, 'dst_id': 75, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 2, 'src_loc': 'ATB', 'src_time': 240, 'dst_id': 3, 'dst_loc': 'ATB', 'dst_time': 255, 'cost': 200, 'N_bus': 150}
# {'src_id': 3, 'src_loc': 'ATB', 'src_time': 255, 'dst_id': 4, 'dst_loc': 'ATB', 'dst_time': 270, 'cost': 200, 'N_bus': 150}
# {'src_id': 4, 'src_loc': 'ATB', 'src_time': 270, 'dst_id': 5, 'dst_loc': 'ATB', 'dst_time': 285, 'cost': 200, 'N_bus': 150}
# {'src_id': 5, 'src_loc': 'ATB', 'src_time': 285, 'dst_id': 10, 'dst_loc': 'ATB', 'dst_time': 300, 'cost': 200, 'N_bus': 150}
# {'src_id': 10, 'src_loc': 'ATB', 'src_time': 300, 'dst_id': 11, 'dst_loc': 'ATB', 'dst_time': 315, 'cost': 200, 'N_bus': 150}
# {'src_id': 11, 'src_loc': 'ATB', 'src_time': 315, 'dst_id': 12, 'dst_loc': 'ATB', 'dst_time': 330, 'cost': 200, 'N_bus': 150}
# {'src_id': 12, 'src_loc': 'ATB', 'src_time': 330, 'dst_id': 13, 'dst_loc': 'ATB', 'dst_time': 345, 'cost': 200, 'N_bus': 150}
# {'src_id': 13, 'src_loc': 'ATB', 'src_time': 345, 'dst_id': 77, 'dst_loc': 'ATB', 'dst_time': 350, 'cost': 200, 'N_bus': 150}
# {'src_id': 77, 'src_loc': 'ATB', 'src_time': 350, 'dst_id': 18, 'dst_loc': 'ATB', 'dst_time': 360, 'cost': 200, 'N_bus': 150}
# {'src_id': 18, 'src_loc': 'ATB', 'src_time': 360, 'dst_id': 79, 'dst_loc': 'ATB', 'dst_time': 365, 'cost': 200, 'N_bus': 150}
# {'src_id': 79, 'src_loc': 'ATB', 'src_time': 365, 'dst_id': 81, 'dst_loc': 'ATB', 'dst_time': 380, 'cost': 200, 'N_bus': 150}
# {'src_id': 81, 'src_loc': 'ATB', 'src_time': 380, 'dst_id': 19, 'dst_loc': 'ATB', 'dst_time': 390, 'cost': 200, 'N_bus': 150}
# {'src_id': 19, 'src_loc': 'ATB', 'src_time': 390, 'dst_id': 83, 'dst_loc': 'ATB', 'dst_time': 395, 'cost': 200, 'N_bus': 150}
# {'src_id': 83, 'src_loc': 'ATB', 'src_time': 395, 'dst_id': 85, 'dst_loc': 'ATB', 'dst_time': 410, 'cost': 200, 'N_bus': 150}
# {'src_id': 85, 'src_loc': 'ATB', 'src_time': 410, 'dst_id': 22, 'dst_loc': 'ATB', 'dst_time': 420, 'cost': 200, 'N_bus': 150}
# {'src_id': 22, 'src_loc': 'ATB', 'src_time': 420, 'dst_id': 87, 'dst_loc': 'ATB', 'dst_time': 425, 'cost': 200, 'N_bus': 150}
# {'src_id': 87, 'src_loc': 'ATB', 'src_time': 425, 'dst_id': 89, 'dst_loc': 'ATB', 'dst_time': 440, 'cost': 200, 'N_bus': 150}
# {'src_id': 89, 'src_loc': 'ATB', 'src_time': 440, 'dst_id': 23, 'dst_loc': 'ATB', 'dst_time': 450, 'cost': 200, 'N_bus': 150}
# {'src_id': 23, 'src_loc': 'ATB', 'src_time': 450, 'dst_id': 91, 'dst_loc': 'ATB', 'dst_time': 455, 'cost': 200, 'N_bus': 150}
# {'src_id': 91, 'src_loc': 'ATB', 'src_time': 455, 'dst_id': 93, 'dst_loc': 'ATB', 'dst_time': 470, 'cost': 200, 'N_bus': 150}
# {'src_id': 93, 'src_loc': 'ATB', 'src_time': 470, 'dst_id': 26, 'dst_loc': 'ATB', 'dst_time': 480, 'cost': 200, 'N_bus': 150}
# {'src_id': 26, 'src_loc': 'ATB', 'src_time': 480, 'dst_id': 95, 'dst_loc': 'ATB', 'dst_time': 500, 'cost': 200, 'N_bus': 150}
# {'src_id': 95, 'src_loc': 'ATB', 'src_time': 500, 'dst_id': 27, 'dst_loc': 'ATB', 'dst_time': 510, 'cost': 200, 'N_bus': 150}
# {'src_id': 27, 'src_loc': 'ATB', 'src_time': 510, 'dst_id': 97, 'dst_loc': 'ATB', 'dst_time': 530, 'cost': 200, 'N_bus': 150}
# {'src_id': 97, 'src_loc': 'ATB', 'src_time': 530, 'dst_id': 30, 'dst_loc': 'ATB', 'dst_time': 540, 'cost': 200, 'N_bus': 150}
# {'src_id': 30, 'src_loc': 'ATB', 'src_time': 540, 'dst_id': 99, 'dst_loc': 'ATB', 'dst_time': 560, 'cost': 200, 'N_bus': 150}
# {'src_id': 99, 'src_loc': 'ATB', 'src_time': 560, 'dst_id': 31, 'dst_loc': 'ATB', 'dst_time': 570, 'cost': 200, 'N_bus': 150}
# {'src_id': 31, 'src_loc': 'ATB', 'src_time': 570, 'dst_id': 101, 'dst_loc': 'ATB', 'dst_time': 590, 'cost': 200, 'N_bus': 150}
# {'src_id': 101, 'src_loc': 'ATB', 'src_time': 590, 'dst_id': 34, 'dst_loc': 'ATB', 'dst_time': 600, 'cost': 200, 'N_bus': 150}
# {'src_id': 34, 'src_loc': 'ATB', 'src_time': 600, 'dst_id': 35, 'dst_loc': 'ATB', 'dst_time': 615, 'cost': 200, 'N_bus': 150}
# {'src_id': 35, 'src_loc': 'ATB', 'src_time': 615, 'dst_id': 103, 'dst_loc': 'ATB', 'dst_time': 620, 'cost': 200, 'N_bus': 150}
# {'src_id': 103, 'src_loc': 'ATB', 'src_time': 620, 'dst_id': 36, 'dst_loc': 'ATB', 'dst_time': 630, 'cost': 200, 'N_bus': 150}
# {'src_id': 36, 'src_loc': 'ATB', 'src_time': 630, 'dst_id': 37, 'dst_loc': 'ATB', 'dst_time': 645, 'cost': 200, 'N_bus': 150}
# {'src_id': 37, 'src_loc': 'ATB', 'src_time': 645, 'dst_id': 105, 'dst_loc': 'ATB', 'dst_time': 650, 'cost': 200, 'N_bus': 150}
# {'src_id': 105, 'src_loc': 'ATB', 'src_time': 650, 'dst_id': 42, 'dst_loc': 'ATB', 'dst_time': 660, 'cost': 200, 'N_bus': 150}
# {'src_id': 42, 'src_loc': 'ATB', 'src_time': 660, 'dst_id': 107, 'dst_loc': 'ATB', 'dst_time': 680, 'cost': 200, 'N_bus': 150}
# {'src_id': 107, 'src_loc': 'ATB', 'src_time': 680, 'dst_id': 43, 'dst_loc': 'ATB', 'dst_time': 690, 'cost': 200, 'N_bus': 150}
# {'src_id': 43, 'src_loc': 'ATB', 'src_time': 690, 'dst_id': 109, 'dst_loc': 'ATB', 'dst_time': 710, 'cost': 200, 'N_bus': 150}
# {'src_id': 109, 'src_loc': 'ATB', 'src_time': 710, 'dst_id': 46, 'dst_loc': 'ATB', 'dst_time': 720, 'cost': 200, 'N_bus': 150}
# {'src_id': 46, 'src_loc': 'ATB', 'src_time': 720, 'dst_id': 111, 'dst_loc': 'ATB', 'dst_time': 725, 'cost': 200, 'N_bus': 150}
# {'src_id': 111, 'src_loc': 'ATB', 'src_time': 725, 'dst_id': 113, 'dst_loc': 'ATB', 'dst_time': 740, 'cost': 200, 'N_bus': 150}
# {'src_id': 113, 'src_loc': 'ATB', 'src_time': 740, 'dst_id': 47, 'dst_loc': 'ATB', 'dst_time': 750, 'cost': 200, 'N_bus': 150}
# {'src_id': 47, 'src_loc': 'ATB', 'src_time': 750, 'dst_id': 115, 'dst_loc': 'ATB', 'dst_time': 755, 'cost': 200, 'N_bus': 150}
# {'src_id': 115, 'src_loc': 'ATB', 'src_time': 755, 'dst_id': 117, 'dst_loc': 'ATB', 'dst_time': 770, 'cost': 200, 'N_bus': 150}
# {'src_id': 117, 'src_loc': 'ATB', 'src_time': 770, 'dst_id': 50, 'dst_loc': 'ATB', 'dst_time': 780, 'cost': 200, 'N_bus': 150}
# {'src_id': 50, 'src_loc': 'ATB', 'src_time': 780, 'dst_id': 119, 'dst_loc': 'ATB', 'dst_time': 800, 'cost': 200, 'N_bus': 150}
# {'src_id': 119, 'src_loc': 'ATB', 'src_time': 800, 'dst_id': 51, 'dst_loc': 'ATB', 'dst_time': 810, 'cost': 200, 'N_bus': 150}
# {'src_id': 51, 'src_loc': 'ATB', 'src_time': 810, 'dst_id': 121, 'dst_loc': 'ATB', 'dst_time': 830, 'cost': 200, 'N_bus': 150}
# {'src_id': 121, 'src_loc': 'ATB', 'src_time': 830, 'dst_id': 54, 'dst_loc': 'ATB', 'dst_time': 840, 'cost': 200, 'N_bus': 150}
# {'src_id': 54, 'src_loc': 'ATB', 'src_time': 840, 'dst_id': 123, 'dst_loc': 'ATB', 'dst_time': 860, 'cost': 200, 'N_bus': 150}
# {'src_id': 123, 'src_loc': 'ATB', 'src_time': 860, 'dst_id': 125, 'dst_loc': 'ATB', 'dst_time': 890, 'cost': 200, 'N_bus': 150}
# {'src_id': 125, 'src_loc': 'ATB', 'src_time': 890, 'dst_id': 127, 'dst_loc': 'ATB', 'dst_time': 920, 'cost': 200, 'N_bus': 150}
# {'src_id': 127, 'src_loc': 'ATB', 'src_time': 920, 'dst_id': 129, 'dst_loc': 'ATB', 'dst_time': 950, 'cost': 200, 'N_bus': 150}
# {'src_id': 129, 'src_loc': 'ATB', 'src_time': 950, 'dst_id': 56, 'dst_loc': 'ATB', 'dst_time': 960, 'cost': 200, 'N_bus': 150}
# {'src_id': 56, 'src_loc': 'ATB', 'src_time': 960, 'dst_id': 57, 'dst_loc': 'ATB', 'dst_time': 990, 'cost': 200, 'N_bus': 150}
# {'src_id': 57, 'src_loc': 'ATB', 'src_time': 990, 'dst_id': 60, 'dst_loc': 'ATB', 'dst_time': 1020, 'cost': 200, 'N_bus': 150}
# {'src_id': 60, 'src_loc': 'ATB', 'src_time': 1020, 'dst_id': 131, 'dst_loc': 'ATB', 'dst_time': 1070, 'cost': 200, 'N_bus': 150}
# {'src_id': 131, 'src_loc': 'ATB', 'src_time': 1070, 'dst_id': 62, 'dst_loc': 'ATB', 'dst_time': 1080, 'cost': 200, 'N_bus': 150}
# {'src_id': 62, 'src_loc': 'ATB', 'src_time': 1080, 'dst_id': 133, 'dst_loc': 'ATB', 'dst_time': 1100, 'cost': 200, 'N_bus': 150}
# {'src_id': 133, 'src_loc': 'ATB', 'src_time': 1100, 'dst_id': 63, 'dst_loc': 'ATB', 'dst_time': 1110, 'cost': 200, 'N_bus': 150}
# {'src_id': 63, 'src_loc': 'ATB', 'src_time': 1110, 'dst_id': 135, 'dst_loc': 'ATB', 'dst_time': 1130, 'cost': 200, 'N_bus': 150}
# {'src_id': 135, 'src_loc': 'ATB', 'src_time': 1130, 'dst_id': 66, 'dst_loc': 'ATB', 'dst_time': 1140, 'cost': 200, 'N_bus': 150}
# {'src_id': 66, 'src_loc': 'ATB', 'src_time': 1140, 'dst_id': 137, 'dst_loc': 'ATB', 'dst_time': 1190, 'cost': 200, 'N_bus': 150}
# {'src_id': 137, 'src_loc': 'ATB', 'src_time': 1190, 'dst_id': 69, 'dst_loc': 'ATB', 'dst_time': 1200, 'cost': 200, 'N_bus': 150}
# {'src_id': 69, 'src_loc': 'ATB', 'src_time': 1200, 'dst_id': 139, 'dst_loc': 'ATB', 'dst_time': 1220, 'cost': 200, 'N_bus': 150}
# {'src_id': 139, 'src_loc': 'ATB', 'src_time': 1220, 'dst_id': 70, 'dst_loc': 'ATB', 'dst_time': 1230, 'cost': 200, 'N_bus': 150}
# {'src_id': 70, 'src_loc': 'ATB', 'src_time': 1230, 'dst_id': 141, 'dst_loc': 'ATB', 'dst_time': 1250, 'cost': 200, 'N_bus': 150}
# {'src_id': 141, 'src_loc': 'ATB', 'src_time': 1250, 'dst_id': 73, 'dst_loc': 'ATB', 'dst_time': 1260, 'cost': 200, 'N_bus': 150}
# {'src_id': 73, 'src_loc': 'ATB', 'src_time': 1260, 'dst_id': 142, 'dst_loc': 'ATB', 'dst_time': 1280, 'cost': 200, 'N_bus': 150}
# {'src_id': 142, 'src_loc': 'ATB', 'src_time': 1280, 'dst_id': 144, 'dst_loc': 'ATB', 'dst_time': 1310, 'cost': 200, 'N_bus': 150}
# {'src_id': 144, 'src_loc': 'ATB', 'src_time': 1310, 'dst_id': 146, 'dst_loc': 'ATB', 'dst_time': 1340, 'cost': 200, 'N_bus': 150}
# {'src_id': 146, 'src_loc': 'ATB', 'src_time': 1340, 'dst_id': 148, 'dst_loc': 'ATB', 'dst_time': 1370, 'cost': 200, 'N_bus': 150}
# {'src_id': 6, 'src_loc': 'HSK', 'src_time': 240, 'dst_id': 7, 'dst_loc': 'HSK', 'dst_time': 255, 'cost': 200, 'N_bus': 150}
# {'src_id': 7, 'src_loc': 'HSK', 'src_time': 255, 'dst_id': 8, 'dst_loc': 'HSK', 'dst_time': 270, 'cost': 200, 'N_bus': 150}
# {'src_id': 8, 'src_loc': 'HSK', 'src_time': 270, 'dst_id': 9, 'dst_loc': 'HSK', 'dst_time': 285, 'cost': 200, 'N_bus': 150}
# {'src_id': 9, 'src_loc': 'HSK', 'src_time': 285, 'dst_id': 14, 'dst_loc': 'HSK', 'dst_time': 300, 'cost': 200, 'N_bus': 150}
# {'src_id': 14, 'src_loc': 'HSK', 'src_time': 300, 'dst_id': 15, 'dst_loc': 'HSK', 'dst_time': 315, 'cost': 200, 'N_bus': 150}
# {'src_id': 15, 'src_loc': 'HSK', 'src_time': 315, 'dst_id': 16, 'dst_loc': 'HSK', 'dst_time': 330, 'cost': 200, 'N_bus': 150}
# {'src_id': 16, 'src_loc': 'HSK', 'src_time': 330, 'dst_id': 17, 'dst_loc': 'HSK', 'dst_time': 345, 'cost': 200, 'N_bus': 150}
# {'src_id': 17, 'src_loc': 'HSK', 'src_time': 345, 'dst_id': 76, 'dst_loc': 'HSK', 'dst_time': 350, 'cost': 200, 'N_bus': 150}
# {'src_id': 76, 'src_loc': 'HSK', 'src_time': 350, 'dst_id': 20, 'dst_loc': 'HSK', 'dst_time': 360, 'cost': 200, 'N_bus': 150}
# {'src_id': 20, 'src_loc': 'HSK', 'src_time': 360, 'dst_id': 78, 'dst_loc': 'HSK', 'dst_time': 365, 'cost': 200, 'N_bus': 150}
# {'src_id': 78, 'src_loc': 'HSK', 'src_time': 365, 'dst_id': 80, 'dst_loc': 'HSK', 'dst_time': 380, 'cost': 200, 'N_bus': 150}
# {'src_id': 80, 'src_loc': 'HSK', 'src_time': 380, 'dst_id': 21, 'dst_loc': 'HSK', 'dst_time': 390, 'cost': 200, 'N_bus': 150}
# {'src_id': 21, 'src_loc': 'HSK', 'src_time': 390, 'dst_id': 82, 'dst_loc': 'HSK', 'dst_time': 395, 'cost': 200, 'N_bus': 150}
# {'src_id': 82, 'src_loc': 'HSK', 'src_time': 395, 'dst_id': 84, 'dst_loc': 'HSK', 'dst_time': 410, 'cost': 200, 'N_bus': 150}
# {'src_id': 84, 'src_loc': 'HSK', 'src_time': 410, 'dst_id': 24, 'dst_loc': 'HSK', 'dst_time': 420, 'cost': 200, 'N_bus': 150}
# {'src_id': 24, 'src_loc': 'HSK', 'src_time': 420, 'dst_id': 86, 'dst_loc': 'HSK', 'dst_time': 425, 'cost': 200, 'N_bus': 150}
# {'src_id': 86, 'src_loc': 'HSK', 'src_time': 425, 'dst_id': 88, 'dst_loc': 'HSK', 'dst_time': 440, 'cost': 200, 'N_bus': 150}
# {'src_id': 88, 'src_loc': 'HSK', 'src_time': 440, 'dst_id': 25, 'dst_loc': 'HSK', 'dst_time': 450, 'cost': 200, 'N_bus': 150}
# {'src_id': 25, 'src_loc': 'HSK', 'src_time': 450, 'dst_id': 90, 'dst_loc': 'HSK', 'dst_time': 455, 'cost': 200, 'N_bus': 150}
# {'src_id': 90, 'src_loc': 'HSK', 'src_time': 455, 'dst_id': 92, 'dst_loc': 'HSK', 'dst_time': 470, 'cost': 200, 'N_bus': 150}
# {'src_id': 92, 'src_loc': 'HSK', 'src_time': 470, 'dst_id': 28, 'dst_loc': 'HSK', 'dst_time': 480, 'cost': 200, 'N_bus': 150}
# {'src_id': 28, 'src_loc': 'HSK', 'src_time': 480, 'dst_id': 94, 'dst_loc': 'HSK', 'dst_time': 500, 'cost': 200, 'N_bus': 150}
# {'src_id': 94, 'src_loc': 'HSK', 'src_time': 500, 'dst_id': 29, 'dst_loc': 'HSK', 'dst_time': 510, 'cost': 200, 'N_bus': 150}
# {'src_id': 29, 'src_loc': 'HSK', 'src_time': 510, 'dst_id': 96, 'dst_loc': 'HSK', 'dst_time': 530, 'cost': 200, 'N_bus': 150}
# {'src_id': 96, 'src_loc': 'HSK', 'src_time': 530, 'dst_id': 32, 'dst_loc': 'HSK', 'dst_time': 540, 'cost': 200, 'N_bus': 150}
# {'src_id': 32, 'src_loc': 'HSK', 'src_time': 540, 'dst_id': 98, 'dst_loc': 'HSK', 'dst_time': 560, 'cost': 200, 'N_bus': 150}
# {'src_id': 98, 'src_loc': 'HSK', 'src_time': 560, 'dst_id': 33, 'dst_loc': 'HSK', 'dst_time': 570, 'cost': 200, 'N_bus': 150}
# {'src_id': 33, 'src_loc': 'HSK', 'src_time': 570, 'dst_id': 100, 'dst_loc': 'HSK', 'dst_time': 590, 'cost': 200, 'N_bus': 150}
# {'src_id': 100, 'src_loc': 'HSK', 'src_time': 590, 'dst_id': 38, 'dst_loc': 'HSK', 'dst_time': 600, 'cost': 200, 'N_bus': 150}
# {'src_id': 38, 'src_loc': 'HSK', 'src_time': 600, 'dst_id': 39, 'dst_loc': 'HSK', 'dst_time': 615, 'cost': 200, 'N_bus': 150}
# {'src_id': 39, 'src_loc': 'HSK', 'src_time': 615, 'dst_id': 102, 'dst_loc': 'HSK', 'dst_time': 620, 'cost': 200, 'N_bus': 150}
# {'src_id': 102, 'src_loc': 'HSK', 'src_time': 620, 'dst_id': 40, 'dst_loc': 'HSK', 'dst_time': 630, 'cost': 200, 'N_bus': 150}
# {'src_id': 40, 'src_loc': 'HSK', 'src_time': 630, 'dst_id': 41, 'dst_loc': 'HSK', 'dst_time': 645, 'cost': 200, 'N_bus': 150}
# {'src_id': 41, 'src_loc': 'HSK', 'src_time': 645, 'dst_id': 104, 'dst_loc': 'HSK', 'dst_time': 650, 'cost': 200, 'N_bus': 150}
# {'src_id': 104, 'src_loc': 'HSK', 'src_time': 650, 'dst_id': 44, 'dst_loc': 'HSK', 'dst_time': 660, 'cost': 200, 'N_bus': 150}
# {'src_id': 44, 'src_loc': 'HSK', 'src_time': 660, 'dst_id': 106, 'dst_loc': 'HSK', 'dst_time': 680, 'cost': 200, 'N_bus': 150}
# {'src_id': 106, 'src_loc': 'HSK', 'src_time': 680, 'dst_id': 45, 'dst_loc': 'HSK', 'dst_time': 690, 'cost': 200, 'N_bus': 150}
# {'src_id': 45, 'src_loc': 'HSK', 'src_time': 690, 'dst_id': 108, 'dst_loc': 'HSK', 'dst_time': 710, 'cost': 200, 'N_bus': 150}
# {'src_id': 108, 'src_loc': 'HSK', 'src_time': 710, 'dst_id': 48, 'dst_loc': 'HSK', 'dst_time': 720, 'cost': 200, 'N_bus': 150}
# {'src_id': 48, 'src_loc': 'HSK', 'src_time': 720, 'dst_id': 110, 'dst_loc': 'HSK', 'dst_time': 725, 'cost': 200, 'N_bus': 150}
# {'src_id': 110, 'src_loc': 'HSK', 'src_time': 725, 'dst_id': 112, 'dst_loc': 'HSK', 'dst_time': 740, 'cost': 200, 'N_bus': 150}
# {'src_id': 112, 'src_loc': 'HSK', 'src_time': 740, 'dst_id': 49, 'dst_loc': 'HSK', 'dst_time': 750, 'cost': 200, 'N_bus': 150}
# {'src_id': 49, 'src_loc': 'HSK', 'src_time': 750, 'dst_id': 114, 'dst_loc': 'HSK', 'dst_time': 755, 'cost': 200, 'N_bus': 150}
# {'src_id': 114, 'src_loc': 'HSK', 'src_time': 755, 'dst_id': 116, 'dst_loc': 'HSK', 'dst_time': 770, 'cost': 200, 'N_bus': 150}
# {'src_id': 116, 'src_loc': 'HSK', 'src_time': 770, 'dst_id': 52, 'dst_loc': 'HSK', 'dst_time': 780, 'cost': 200, 'N_bus': 150}
# {'src_id': 52, 'src_loc': 'HSK', 'src_time': 780, 'dst_id': 118, 'dst_loc': 'HSK', 'dst_time': 800, 'cost': 200, 'N_bus': 150}
# {'src_id': 118, 'src_loc': 'HSK', 'src_time': 800, 'dst_id': 53, 'dst_loc': 'HSK', 'dst_time': 810, 'cost': 200, 'N_bus': 150}
# {'src_id': 53, 'src_loc': 'HSK', 'src_time': 810, 'dst_id': 120, 'dst_loc': 'HSK', 'dst_time': 830, 'cost': 200, 'N_bus': 150}
# {'src_id': 120, 'src_loc': 'HSK', 'src_time': 830, 'dst_id': 55, 'dst_loc': 'HSK', 'dst_time': 840, 'cost': 200, 'N_bus': 150}
# {'src_id': 55, 'src_loc': 'HSK', 'src_time': 840, 'dst_id': 122, 'dst_loc': 'HSK', 'dst_time': 860, 'cost': 200, 'N_bus': 150}
# {'src_id': 122, 'src_loc': 'HSK', 'src_time': 860, 'dst_id': 124, 'dst_loc': 'HSK', 'dst_time': 890, 'cost': 200, 'N_bus': 150}
# {'src_id': 124, 'src_loc': 'HSK', 'src_time': 890, 'dst_id': 126, 'dst_loc': 'HSK', 'dst_time': 920, 'cost': 200, 'N_bus': 150}
# {'src_id': 126, 'src_loc': 'HSK', 'src_time': 920, 'dst_id': 128, 'dst_loc': 'HSK', 'dst_time': 950, 'cost': 200, 'N_bus': 150}
# {'src_id': 128, 'src_loc': 'HSK', 'src_time': 950, 'dst_id': 58, 'dst_loc': 'HSK', 'dst_time': 960, 'cost': 200, 'N_bus': 150}
# {'src_id': 58, 'src_loc': 'HSK', 'src_time': 960, 'dst_id': 59, 'dst_loc': 'HSK', 'dst_time': 990, 'cost': 200, 'N_bus': 150}
# {'src_id': 59, 'src_loc': 'HSK', 'src_time': 990, 'dst_id': 61, 'dst_loc': 'HSK', 'dst_time': 1020, 'cost': 200, 'N_bus': 150}
# {'src_id': 61, 'src_loc': 'HSK', 'src_time': 1020, 'dst_id': 130, 'dst_loc': 'HSK', 'dst_time': 1070, 'cost': 200, 'N_bus': 150}
# {'src_id': 130, 'src_loc': 'HSK', 'src_time': 1070, 'dst_id': 64, 'dst_loc': 'HSK', 'dst_time': 1080, 'cost': 200, 'N_bus': 150}
# {'src_id': 64, 'src_loc': 'HSK', 'src_time': 1080, 'dst_id': 132, 'dst_loc': 'HSK', 'dst_time': 1100, 'cost': 200, 'N_bus': 150}
# {'src_id': 132, 'src_loc': 'HSK', 'src_time': 1100, 'dst_id': 65, 'dst_loc': 'HSK', 'dst_time': 1110, 'cost': 200, 'N_bus': 150}
# {'src_id': 65, 'src_loc': 'HSK', 'src_time': 1110, 'dst_id': 134, 'dst_loc': 'HSK', 'dst_time': 1130, 'cost': 200, 'N_bus': 150}
# {'src_id': 134, 'src_loc': 'HSK', 'src_time': 1130, 'dst_id': 67, 'dst_loc': 'HSK', 'dst_time': 1140, 'cost': 200, 'N_bus': 150}
# {'src_id': 67, 'src_loc': 'HSK', 'src_time': 1140, 'dst_id': 68, 'dst_loc': 'HSK', 'dst_time': 1170, 'cost': 200, 'N_bus': 150}
# {'src_id': 68, 'src_loc': 'HSK', 'src_time': 1170, 'dst_id': 136, 'dst_loc': 'HSK', 'dst_time': 1190, 'cost': 200, 'N_bus': 150}
# {'src_id': 136, 'src_loc': 'HSK', 'src_time': 1190, 'dst_id': 71, 'dst_loc': 'HSK', 'dst_time': 1200, 'cost': 200, 'N_bus': 150}
# {'src_id': 71, 'src_loc': 'HSK', 'src_time': 1200, 'dst_id': 138, 'dst_loc': 'HSK', 'dst_time': 1220, 'cost': 200, 'N_bus': 150}
# {'src_id': 138, 'src_loc': 'HSK', 'src_time': 1220, 'dst_id': 72, 'dst_loc': 'HSK', 'dst_time': 1230, 'cost': 200, 'N_bus': 150}
# {'src_id': 72, 'src_loc': 'HSK', 'src_time': 1230, 'dst_id': 140, 'dst_loc': 'HSK', 'dst_time': 1250, 'cost': 200, 'N_bus': 150}
# {'src_id': 140, 'src_loc': 'HSK', 'src_time': 1250, 'dst_id': 74, 'dst_loc': 'HSK', 'dst_time': 1260, 'cost': 200, 'N_bus': 150}
# {'src_id': 74, 'src_loc': 'HSK', 'src_time': 1260, 'dst_id': 143, 'dst_loc': 'HSK', 'dst_time': 1310, 'cost': 200, 'N_bus': 150}
# {'src_id': 143, 'src_loc': 'HSK', 'src_time': 1310, 'dst_id': 145, 'dst_loc': 'HSK', 'dst_time': 1340, 'cost': 200, 'N_bus': 150}
# {'src_id': 145, 'src_loc': 'HSK', 'src_time': 1340, 'dst_id': 147, 'dst_loc': 'HSK', 'dst_time': 1370, 'cost': 200, 'N_bus': 150}
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_LPMethod                                3
# Tried aggregator 1 time.
# MIP Presolve eliminated 171 rows and 48 columns.
# MIP Presolve modified 239550 coefficients.
# Reduced MIP has 131800 rows, 76950 columns, and 483750 nonzeros.
# Reduced MIP has 54600 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.55 sec. (799.10 ticks)
# Probing fixed 1200 vars, tightened 0 bounds.
# Probing time = 6.72 sec. (78.80 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated 1800 rows and 1200 columns.
# Reduced MIP has 130000 rows, 75750 columns, and 475350 nonzeros.
# Reduced MIP has 53400 binaries, 150 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.39 sec. (462.00 ticks)
# Probing time = 6.08 sec. (29.83 ticks)
# Clique table members: 300259.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 32 threads.
# Root relaxation solution time = 0.84 sec. (952.33 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0    43280.0000   765                  43280.0000       15
#       0     0    43280.0000  2260                  Cuts: 2397     8057
#       0     0    43280.0000  2307                  Cuts: 3810    13278
# Heuristic still looking.
#       0     2    43280.0000  1950                  43280.0000    14659
# Elapsed time = 175.30 sec. (122428.56 ticks, tree = 0.02 MB, solutions = 0)
#       1     3    43286.6358  1514                  43280.0000    18782
#       2     4    43286.6358   875                  43280.0000    22107
#       3     3    43280.0000  1676                  43280.0000    17889
#       5     4    43286.6358  1279                  43280.0000    19934
#       6     5    43286.6358  1094                  43280.0000    23990
#       8     5    infeasible                        43280.0000    29627
#       9     6    43286.6358  1365                  43280.0000    30218
#      10     5    43293.7346  1013                  43280.0000    24438
#      11     6    43287.3379  1311                  43280.0000    29530
#      13     7    infeasible                        43286.6358    59898
# Elapsed time = 199.00 sec. (137241.44 ticks, tree = 0.05 MB, solutions = 0)
#      14     6    43286.6358  1283                  43286.6358    47340
#      16     7    43294.4366  1267                  43286.6358    38156
#      20     9    infeasible                        43286.6358   115722
#      22     8    43294.7876  1205                  43286.6358    55640
#      25     9    43295.1877  1102                  43286.6358    82339
#      29    12    infeasible                        43286.6358   167276
#      33    11    43300.3998   956                  43286.6358   106396
#      42    13    43324.4096  1081                  43294.4366   162470
#      51    14    43295.4872  1135                  43295.1877   171778
#      54    16    44574.3387  1212                  43295.1877   206758
# Elapsed time = 241.92 sec. (151359.46 ticks, tree = 0.05 MB, solutions = 0)
#      57    20    infeasible                        43295.1877   308413
#     450    46    infeasible                        43388.0466  2185392
#     455    57    49800.8173  1009                  43388.0466  2012197
# Elapsed time = 707.80 sec. (221861.39 ticks, tree = 0.16 MB, solutions = 0)
#     465    46    infeasible                        43388.0466  2186925
#     467    52    infeasible                        43388.0466  1903409
#     469    28    infeasible                        43388.0466  2526608
#     471    48    51134.2857  1043                  43388.0466  2233389
#     476    49    52891.3372  1149                  43388.0466  2243482
#     481    50    51934.1506  1208                  43388.0466  2111289
#     489    40    51889.4085  1000                  43388.0466  2360861
#     499    25    infeasible                        43388.0466  2594627
#     501    16    infeasible                        44721.9992  2752665
#     509    14    infeasible                        47099.4892  2833426
# Elapsed time = 771.84 sec. (234714.98 ticks, tree = 0.02 MB, solutions = 0)
#     510    17    infeasible                        47099.4892  2737482
#     512    29    51057.5864  1069                  47099.4892  2563367
#     517    33    49818.0230  1147                  47165.7143  2441163
#     520    17    infeasible                        47165.7143  2778081
#     523    12    infeasible                        47165.7143  2875906
#     525    12    infeasible                        47165.7143  2903657
#     530     7    infeasible                        47165.7143  2959275
#     533    57    50171.5266   848                  47165.7143  2032824
#     534    16    47617.9362   926                  47165.7143  2833649
#     541     7    47628.3642   997                  47617.9362  3026709
# Elapsed time = 823.91 sec. (251092.51 ticks, tree = 0.06 MB, solutions = 0)
#     552    11    infeasible                        47617.9362  3085066
#     568    12    infeasible                        47656.9356  3118872
#     582    17    50989.3056   868                  47656.9356  3165341
#     622    16    47785.1758   623                  47656.9356  3131044
#     680    33    52252.5161   485                  47899.4616  3201561
#     725    26    52247.0432   465                  47899.4616  3207278
#     777    20    infeasible                        47899.4616  3557500
#
# Cover cuts applied:  16
# Implied bound cuts applied:  19545
# Flow cuts applied:  1119
# Mixed integer rounding cuts applied:  1018
# Zero-half cuts applied:  3
# Gomory fractional cuts applied:  12
#
# Root node processing (before b&c):
#   Real time             =  168.27 sec. (121915.59 ticks)
# Parallel b&c, 32 threads:
#   Real time             =  773.36 sec. (160267.49 ticks)
#   Sync time (average)   =  303.27 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =  941.62 sec. (282183.08 ticks)
# No feasible solution found.

# %%
# E = cleaned_E
from docplex.mp.model import Model
from datetime import timedelta

# --- CONSTANTS ---
HOURS = 24
MINUTES_IN_DAY = 1440
MinUtilTime = 150
MinUtilTime_2 = 150
MaxUtilTime = 1000

vehicle_fixed_cost = 1000
freq_penalty = 1000

nvehicle = 150
K = range(nvehicle)
H = range(HOURS)

bigM = 1440

freq1 = [0]*17 + [3, 4, 5, 4, 5, 0, 0]  # ATB
freq2 = [0]*17 + [3, 4, 5, 4, 5, 0, 0]  # HSK
# freq1 = [0, 0, 0, 0, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 0, 0]
# freq2 = [0, 0, 0, 0, 4, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 0, 0]

arc_data = {
    ("X", "X"): (0, 150),
    ("X", "HSK"): (10, 150),
    ("X", "ATB"): (40, 150),
    ("HSK", "HSK"): (200, 150),
    ("ATB", "ATB"): (200, 150),
    ("HSK", "ATB"): (110, 1),
    ("ATB", "HSK"): (110, 1),
    ("HSK", "X"): (10, 150),
    ("ATB", "X"): (40, 150)
}

transitions = {"ATB": "HSK", "HSK": "ATB"}
travel_time = {("ATB", "HSK"): 110, ("HSK", "ATB"): 110}

# --- NODES ---
nodes = []
node_id = 1
nodes.append({'id': node_id, 'time': 0, 'loc': 'X'})
start_node_id = node_id
node_id += 1

for hour in H:
    for i in range(freq1[hour]):
        time_val = hour * 60 + (i * 60 // max(freq1[hour], 1))
        nodes.append({'id': node_id, 'time': time_val, 'loc': 'ATB'})
        node_id += 1
    for i in range(freq2[hour]):
        time_val = hour * 60 + (i * 60 // max(freq2[hour], 1))
        nodes.append({'id': node_id, 'time': time_val, 'loc': 'HSK'})
        node_id += 1

nodes.append({'id': node_id, 'time': MINUTES_IN_DAY, 'loc': 'X'})
end_node_id = node_id
node_id += 1

nodes.sort(key=lambda x: x['time'])
V = nodes.copy()

# --- INITIAL ARCS ---
E = []
synthetic_id = node_id
synthetic_nodes = []

for node in nodes:
    loc = node['loc']
    dst_time = node['time']
    if loc in ['ATB', 'HSK']:
        cost, N_bus = arc_data[('X', loc)]
        if dst_time >= cost:
            E.append({
                'src': {'id': start_node_id, 'time': 0, 'loc': 'X'},
                'dst': {'id': node['id'], 'time': dst_time, 'loc': loc},
                'cost': cost,
                'N_bus': N_bus
            })

for node in nodes:
    loc = node['loc']
    time = node['time']
    src_id = node['id']

    if loc not in transitions:
        continue

    total_time = 0
    curr_loc = loc
    curr_time = time
    curr_src_id = src_id

    while total_time + travel_time[(curr_loc, transitions[curr_loc])] <= MinUtilTime_2:
        next_loc = transitions[curr_loc]
        cost = travel_time[(curr_loc, next_loc)]
        next_time = curr_time + cost

        if next_time > MINUTES_IN_DAY:
            break

        dst = {'id': synthetic_id, 'time': next_time, 'loc': next_loc}
        synthetic_nodes.append(dst)

        E.append({
            'src': {'id': curr_src_id, 'time': curr_time, 'loc': curr_loc},
            'dst': dst,
            'cost': cost,
            'N_bus': 1
        })

        curr_src_id = synthetic_id
        curr_time = next_time
        curr_loc = next_loc
        synthetic_id += 1
        total_time += cost

    if curr_time <= MINUTES_IN_DAY:
        cost_to_X, N_bus_to_X = arc_data[(curr_loc, 'X')]
        E.append({
            'src': {'id': curr_src_id, 'time': curr_time, 'loc': curr_loc},
            'dst': {'id': end_node_id, 'time': MINUTES_IN_DAY, 'loc': 'X'},
            'cost': cost_to_X,
            'N_bus': N_bus_to_X
        })

V.extend(synthetic_nodes)

for node in V:
    node['hhmm'] = str(timedelta(minutes=node['time']))[:-3]

# --- ADD WAITING AND DEADHEADING ARCS ---
MAX_WAIT = 60
augmented_E = E.copy()
unique_keys = set()

# Add existing arcs to unique_keys to avoid duplication later
for e in E:
    arc_key = (
        e['src']['id'], e['src']['time'], e['src']['loc'],
        e['dst']['id'], e['dst']['time'], e['dst']['loc'],
        e['cost'], e['N_bus']
    )
    unique_keys.add(arc_key)

# Waiting arcs
for src in V:
    for dst in V:
        if src['id'] == dst['id']:
            continue
        time_diff = dst['time'] - src['time']
        if src['loc'] == dst['loc'] and 0 < time_diff <= MAX_WAIT:
            arc_key = (
                src['id'], src['time'], src['loc'],
                dst['id'], dst['time'], dst['loc'],
                200, 150
            )
            if arc_key not in unique_keys:
                unique_keys.add(arc_key)
                augmented_E.append({
                    'src': src,
                    'dst': dst,
                    'cost': 200,
                    'N_bus': 150
                })
# Sort nodes by location and time to easily find next closest at same loc
# from collections import defaultdict

# # Group nodes by location
# nodes_by_loc = defaultdict(list)
# for node in V:
#     nodes_by_loc[node['loc']].append(node)

# # Sort nodes by time for each location
# for loc in nodes_by_loc:
#     nodes_by_loc[loc].sort(key=lambda n: n['time'])

# # Create minimal waiting arcs (only to immediate next time at same loc)
# for loc, nodes in nodes_by_loc.items():
#     for i in range(len(nodes) - 1):
#         src = nodes[i]
#         dst = nodes[i + 1]

#         time_diff = dst['time'] - src['time']
#         if 0 < time_diff <= MAX_WAIT:
#             arc_key = (
#                 src['id'], src['time'], src['loc'],
#                 dst['id'], dst['time'], dst['loc'],
#                 200, 150
#             )
#             if arc_key not in unique_keys:
#                 unique_keys.add(arc_key)
#                 augmented_E.append({
#                     'src': src,
#                     'dst': dst,
#                     'cost': 200,
#                     'N_bus': 150
#                 })


# Deadheading arcs
# for src in V:
#     for dst in V:
#         if src['id'] == dst['id'] or src['loc'] == dst['loc']:
#             continue

#         key = (src['loc'], dst['loc'])
#         if key not in arc_data:
#             continue

#         travel_t, cap = arc_data[key]
#         if dst['time'] > src['time'] + travel_t:
#             arc_key = (
#                 src['id'], src['time'], src['loc'],
#                 dst['id'], dst['time'], dst['loc'],
#                 travel_t, cap
#             )
#             if arc_key not in unique_keys:
#                 unique_keys.add(arc_key)
#                 augmented_E.append({
#                     'src': src,
#                     'dst': dst,
#                     'cost': 220,
#                     'N_bus': 150
#                 })
# for src in V:
#     best_arcs_by_dst_loc = {}
    
#     for dst in V:
#         if src['id'] == dst['id'] or src['loc'] == dst['loc']:
#             continue

#         key = (src['loc'], dst['loc'])
#         if key not in arc_data:
#             continue

#         travel_t, cap = arc_data[key]

#         if dst['time'] > src['time'] + travel_t:
#             time_diff = dst['time'] - src['time'] - travel_t

#             # Keep only the best arc (least time diff) per dst location
#             if dst['loc'] not in best_arcs_by_dst_loc or time_diff < best_arcs_by_dst_loc[dst['loc']]['time_diff']:
#                 best_arcs_by_dst_loc[dst['loc']] = {
#                     'dst': dst,
#                     'travel_t': travel_t,
#                     'cap': cap,
#                     'time_diff': time_diff
#                 }

#     # Now select the single best arc among all dst_locs (least time_diff)
#     if best_arcs_by_dst_loc:
#         # Find arc with minimal time_diff overall
#         best_dst_loc = min(best_arcs_by_dst_loc, key=lambda loc: best_arcs_by_dst_loc[loc]['time_diff'])
#         best = best_arcs_by_dst_loc[best_dst_loc]

#         arc_key = (
#             src['id'], src['time'], src['loc'],
#             best['dst']['id'], best['dst']['time'], best['dst']['loc'],
#             best['travel_t'], best['cap']
#         )

#         if arc_key not in unique_keys:
#             unique_keys.add(arc_key)
#             augmented_E.append({
#                 'src': src,
#                 'dst': best['dst'],
#                 'cost': 220,
#                 'N_bus': 150
#             })


# Final cleaned arcs
E = augmented_E
# --- FINAL OUTPUT [unchanged] ---
for arc in E:
    print({
        'src_id': arc['src']['id'],
        'src_loc': arc['src']['loc'],
        'src_time': arc['src']['time'],
        'dst_id': arc['dst']['id'],
        'dst_loc': arc['dst']['loc'],
        'dst_time': arc['dst']['time'],
        'cost': arc['cost'],
        'N_bus': arc['N_bus']
    })
# --- MODEL ---
mdl = Model("VehicleScheduling")
mdl.context.cplex_parameters.lpmethod = 3

x = mdl.binary_var_dict(((e['src']['id'], e['dst']['id'], k) for e in E for k in K), name='x')
z = mdl.binary_var_dict(K, name='z')
T = mdl.continuous_var_dict(K, name='T', lb=0)

node_ids_in_arcs = set()
for e in E:
    node_ids_in_arcs.add(e['src']['id'])
    node_ids_in_arcs.add(e['dst']['id'])

arrival_time = mdl.continuous_var_dict(((k, nid) for k in K for nid in node_ids_in_arcs), name='arr', lb=0, ub=MINUTES_IN_DAY)
freq_slack_ATB = mdl.continuous_var_dict(H, name='freq_slack_ATB', lb=0)
freq_slack_HSK = mdl.continuous_var_dict(H, name='freq_slack_HSK', lb=0)

mdl.minimize(
    mdl.sum(e['cost'] * x[e['src']['id'], e['dst']['id'], k] for e in E for k in K) +
    mdl.sum(vehicle_fixed_cost * z[k] for k in K) 
)

# mdl.minimize(
#     mdl.sum(z[k] for k in K) 
# )
#     # mdl.sum(freq_penalty * (freq_slack_ATB[h] + freq_slack_HSK[h]) for h in H)

for k in K:
    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E) <= bigM * z[k])
    mdl.add_constraint(z[k] <= mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E))

    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['src']['id'] == start_node_id) == z[k])
    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['dst']['id'] == end_node_id) == z[k])

    for node in V:
        i = node['id']
        if i != start_node_id and i != end_node_id:
            mdl.add_constraint(
                mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['src']['id'] == i) ==
                mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['dst']['id'] == i)
            )

for e in E:
    if e['N_bus'] == 1:
        mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for k in K) <= 1)

for k in K:
    mdl.add_constraint(T[k] == mdl.sum(e['cost'] * x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['N_bus'] == 1))
    mdl.add_constraint(T[k] >= MinUtilTime * z[k])
    mdl.add_constraint(T[k] <= MaxUtilTime * z[k])

for e in E:
    for k in K:
        i, j = e['src']['id'], e['dst']['id']
        cost = e['cost']
        mdl.add_constraint(arrival_time[k, j] >= arrival_time[k, i] + cost - bigM * (1 - x.get((i, j, k), 0)))
        mdl.add_constraint(arrival_time[k, j] <= arrival_time[k, i] + cost + bigM * (1 - x.get((i, j, k), 0)))

# for h in H:
#     mdl.add_constraint(
#         mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0)
#                 for k in K
#                 for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'ATB' and (e['src']['time'] // 60) == h)
#         + freq_slack_ATB[h] >= freq1[h]
#     )
#     mdl.add_constraint(
#         mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0)
#                 for k in K
#                 for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'HSK' and (e['src']['time'] // 60) == h)
#         + freq_slack_HSK[h] >= freq2[h]
#     )
for h in H:
    mdl.add_constraint(
        mdl.sum(
            x[e['src']['id'], e['dst']['id'], k]
            for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'ATB' and (e['src']['time'] // 60) == h
            for k in K
        ) >= freq1[h]
    )
    mdl.add_constraint(
        mdl.sum(
            x[e['src']['id'], e['dst']['id'], k]
            for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'HSK' and (e['src']['time'] // 60) == h
            for k in K
        ) >= freq2[h]
    )
solution = mdl.solve(log_output=True)

if solution:
    print("Objective:", solution.objective_value)
    used_vehicles = [k for k in K if z[k].solution_value > 0.5]
    print(f"Number of vehicles used: {len(used_vehicles)}\n")

    for k in used_vehicles:
        print(f"Schedule for Vehicle {k + 1}: Utilization time = {T[k].solution_value:.2f}")
        current_node = start_node_id
        while current_node != end_node_id:
            next_arcs = [e for e in E if e['src']['id'] == current_node and x.get((e['src']['id'], e['dst']['id'], k), 0).solution_value > 0.5]
            if not next_arcs:
                print("  ERROR: Route incomplete or disconnected.")
                break
            arc = next_arcs[0]
            src, dst = arc['src'], arc['dst']
            src_h, src_m = divmod(int(src['time']), 60)
            dst_h, dst_m = divmod(int(dst['time']), 60)
            print(f"  ({src['loc']} at {src_h:02d}:{src_m:02d}) --> ({dst['loc']} at {dst_h:02d}:{dst_m:02d}), cost={arc['cost']}")
            current_node = dst['id']
        print()
else:
    print("No feasible solution found.")

# %%
# E = cleaned_E
from docplex.mp.model import Model
from datetime import timedelta

# --- CONSTANTS ---
HOURS = 24
MINUTES_IN_DAY = 1440
MinUtilTime = 150
MinUtilTime_2 = 150
MaxUtilTime = 1000

vehicle_fixed_cost = 1000
freq_penalty = 1000

nvehicle = 150
K = range(nvehicle)
H = range(HOURS)

bigM = 1440

freq1 = [0]*17 + [3, 4, 5, 2, 1, 0, 0]  # ATB
freq2 = [0]*17 + [3, 4, 5, 2, 1, 0, 0]  # HSK
# freq1 = [0, 0, 0, 0, 4, 4, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 0, 0, 1, 1, 2, 2, 0, 0]
# freq2 = [0, 0, 0, 0, 4, 4, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 0, 0, 1, 1, 2, 2, 0, 0]

arc_data = {
    ("X", "X"): (0, 150),
    ("X", "HSK"): (10, 150),
    ("X", "ATB"): (40, 150),
    ("HSK", "HSK"): (200, 150),
    ("ATB", "ATB"): (200, 150),
    ("HSK", "ATB"): (110, 1),
    ("ATB", "HSK"): (110, 1),
    ("HSK", "X"): (10, 150),
    ("ATB", "X"): (40, 150)
}

transitions = {"ATB": "HSK", "HSK": "ATB"}
travel_time = {("ATB", "HSK"): 110, ("HSK", "ATB"): 110}

# --- NODES ---
nodes = []
node_id = 1
nodes.append({'id': node_id, 'time': 0, 'loc': 'X'})
start_node_id = node_id
node_id += 1

for hour in H:
    for i in range(freq1[hour]):
        time_val = hour * 60 + (i * 60 // max(freq1[hour], 1))
        nodes.append({'id': node_id, 'time': time_val, 'loc': 'ATB'})
        node_id += 1
    for i in range(freq2[hour]):
        time_val = hour * 60 + (i * 60 // max(freq2[hour], 1))
        nodes.append({'id': node_id, 'time': time_val, 'loc': 'HSK'})
        node_id += 1

nodes.append({'id': node_id, 'time': MINUTES_IN_DAY, 'loc': 'X'})
end_node_id = node_id
node_id += 1

nodes.sort(key=lambda x: x['time'])
V = nodes.copy()

# --- INITIAL ARCS ---
E = []
synthetic_id = node_id
synthetic_nodes = []

for node in nodes:
    loc = node['loc']
    dst_time = node['time']
    if loc in ['ATB', 'HSK']:
        cost, N_bus = arc_data[('X', loc)]
        if dst_time >= cost:
            E.append({
                'src': {'id': start_node_id, 'time': 0, 'loc': 'X'},
                'dst': {'id': node['id'], 'time': dst_time, 'loc': loc},
                'cost': cost,
                'N_bus': N_bus
            })

for node in nodes:
    loc = node['loc']
    time = node['time']
    src_id = node['id']

    if loc not in transitions:
        continue

    total_time = 0
    curr_loc = loc
    curr_time = time
    curr_src_id = src_id

    while total_time + travel_time[(curr_loc, transitions[curr_loc])] <= MinUtilTime_2:
        next_loc = transitions[curr_loc]
        cost = travel_time[(curr_loc, next_loc)]
        next_time = curr_time + cost

        if next_time > MINUTES_IN_DAY:
            break

        dst = {'id': synthetic_id, 'time': next_time, 'loc': next_loc}
        synthetic_nodes.append(dst)

        E.append({
            'src': {'id': curr_src_id, 'time': curr_time, 'loc': curr_loc},
            'dst': dst,
            'cost': cost,
            'N_bus': 1
        })

        curr_src_id = synthetic_id
        curr_time = next_time
        curr_loc = next_loc
        synthetic_id += 1
        total_time += cost

    if curr_time <= MINUTES_IN_DAY:
        cost_to_X, N_bus_to_X = arc_data[(curr_loc, 'X')]
        E.append({
            'src': {'id': curr_src_id, 'time': curr_time, 'loc': curr_loc},
            'dst': {'id': end_node_id, 'time': MINUTES_IN_DAY, 'loc': 'X'},
            'cost': cost_to_X,
            'N_bus': N_bus_to_X
        })

V.extend(synthetic_nodes)

for node in V:
    node['hhmm'] = str(timedelta(minutes=node['time']))[:-3]

# --- ADD WAITING AND DEADHEADING ARCS ---
MAX_WAIT = 40
augmented_E = E.copy()
unique_keys = set()

# Add existing arcs to unique_keys to avoid duplication later
for e in E:
    arc_key = (
        e['src']['id'], e['src']['time'], e['src']['loc'],
        e['dst']['id'], e['dst']['time'], e['dst']['loc'],
        e['cost'], e['N_bus']
    )
    unique_keys.add(arc_key)

# Waiting arcs
# for src in V:
#     for dst in V:
#         if src['id'] == dst['id']:
#             continue
#         time_diff = dst['time'] - src['time']
#         if src['loc'] == dst['loc'] and 0 < time_diff <= MAX_WAIT:
#             arc_key = (
#                 src['id'], src['time'], src['loc'],
#                 dst['id'], dst['time'], dst['loc'],
#                 200, 150
#             )
#             if arc_key not in unique_keys:
#                 unique_keys.add(arc_key)
#                 augmented_E.append({
#                     'src': src,
#                     'dst': dst,
#                     'cost': 200,
#                     'N_bus': 150
#                 })
# Sort nodes by location and time to easily find next closest at same loc
from collections import defaultdict

# Group nodes by location
nodes_by_loc = defaultdict(list)
for node in V:
    nodes_by_loc[node['loc']].append(node)

# Sort nodes by time for each location
for loc in nodes_by_loc:
    nodes_by_loc[loc].sort(key=lambda n: n['time'])

# Create minimal waiting arcs (only to immediate next time at same loc)
for loc, nodes in nodes_by_loc.items():
    for i in range(len(nodes) - 1):
        src = nodes[i]
        dst = nodes[i + 1]

        time_diff = dst['time'] - src['time']
        if 0 < time_diff <= MAX_WAIT:
            arc_key = (
                src['id'], src['time'], src['loc'],
                dst['id'], dst['time'], dst['loc'],
                200, 150
            )
            if arc_key not in unique_keys:
                unique_keys.add(arc_key)
                augmented_E.append({
                    'src': src,
                    'dst': dst,
                    'cost': 200,
                    'N_bus': 150
                })


# Deadheading arcs
# for src in V:
#     for dst in V:
#         if src['id'] == dst['id'] or src['loc'] == dst['loc']:
#             continue

#         key = (src['loc'], dst['loc'])
#         if key not in arc_data:
#             continue

#         travel_t, cap = arc_data[key]
#         if dst['time'] > src['time'] + travel_t:
#             arc_key = (
#                 src['id'], src['time'], src['loc'],
#                 dst['id'], dst['time'], dst['loc'],
#                 travel_t, cap
#             )
#             if arc_key not in unique_keys:
#                 unique_keys.add(arc_key)
#                 augmented_E.append({
#                     'src': src,
#                     'dst': dst,
#                     'cost': 100,
#                     'N_bus': 150
#                 }) 
for src in V:
    best_arcs_by_dst_loc = {}
    
    for dst in V:
        if src['id'] == dst['id'] or src['loc'] == dst['loc']:
            continue

        key = (src['loc'], dst['loc'])
        if key not in arc_data:
            continue

        travel_t, cap = arc_data[key]

        if dst['time'] > src['time'] + travel_t:
            time_diff = dst['time'] - src['time'] - travel_t

            # Keep only the best arc (least time diff) per dst location
            if dst['loc'] not in best_arcs_by_dst_loc or time_diff < best_arcs_by_dst_loc[dst['loc']]['time_diff']:
                best_arcs_by_dst_loc[dst['loc']] = {
                    'dst': dst,
                    'travel_t': travel_t,
                    'cap': cap,
                    'time_diff': time_diff
                }

    # Now select the single best arc among all dst_locs (least time_diff)
    if best_arcs_by_dst_loc:
        # Find arc with minimal time_diff overall
        best_dst_loc = min(best_arcs_by_dst_loc, key=lambda loc: best_arcs_by_dst_loc[loc]['time_diff'])
        best = best_arcs_by_dst_loc[best_dst_loc]

        arc_key = (
            src['id'], src['time'], src['loc'],
            best['dst']['id'], best['dst']['time'], best['dst']['loc'],
            best['travel_t'], best['cap']
        )

        if arc_key not in unique_keys:
            unique_keys.add(arc_key)
            augmented_E.append({
                'src': src,
                'dst': best['dst'],
                'cost': 180,
                'N_bus': 150
            })
# depot_return_arcs = []
# X = 'X'  # Depot

# for e in augmented_E:
#     if e['src']['loc'] == X or e['dst']['loc'] == X:
#         continue  # Skip depot arcs

#     src = e['src']
#     dst = e['dst']
#     direct_cost = e['cost']
#     src_to_depot_key = (src['loc'], X)
#     depot_to_dst_key = (X, dst['loc'])

#     if src_to_depot_key in arc_data and depot_to_dst_key in arc_data:
#         src_to_depot_cost, _ = arc_data[src_to_depot_key]
#         depot_to_dst_cost, _ = arc_data[depot_to_dst_key]

#         time_to_depot = src_to_depot_cost
#         time_from_depot = depot_to_dst_cost
#         total_depot_time = time_to_depot + time_from_depot

#         if dst['time'] >= src['time'] + total_depot_time:
#             depot_total_cost = src_to_depot_cost + depot_to_dst_cost

#             if depot_total_cost < direct_cost:
#                 arc_key = (
#                     src['id'], src['time'], src['loc'],
#                     dst['id'], dst['time'], dst['loc'],
#                     depot_total_cost, e['N_bus']
#                 )
#                 if arc_key not in unique_keys:
#                     unique_keys.add(arc_key)
#                     depot_return_arcs.append({
#                         'src': src,
#                         'dst': dst,
#                         'cost': depot_total_cost,
#                         'N_bus': e['N_bus']
#                     })
#                 # Remove the direct expensive arc
#                 augmented_E.remove(e)

# augmented_E.extend(depot_return_arcs)


# Final cleaned arcs
E = augmented_E
# --- FINAL OUTPUT [unchanged] ---
for arc in E:
    print({
        'src_id': arc['src']['id'],
        'src_loc': arc['src']['loc'],
        'src_time': arc['src']['time'],
        'dst_id': arc['dst']['id'],
        'dst_loc': arc['dst']['loc'],
        'dst_time': arc['dst']['time'],
        'cost': arc['cost'],
        'N_bus': arc['N_bus']
    })
# --- MODEL ---
mdl = Model("VehicleScheduling")
mdl.context.cplex_parameters.lpmethod = 3

x = mdl.binary_var_dict(((e['src']['id'], e['dst']['id'], k) for e in E for k in K), name='x')
z = mdl.binary_var_dict(K, name='z')
T = mdl.continuous_var_dict(K, name='T', lb=0)

node_ids_in_arcs = set()
for e in E:
    node_ids_in_arcs.add(e['src']['id'])
    node_ids_in_arcs.add(e['dst']['id'])

arrival_time = mdl.continuous_var_dict(((k, nid) for k in K for nid in node_ids_in_arcs), name='arr', lb=0, ub=MINUTES_IN_DAY)
freq_slack_ATB = mdl.continuous_var_dict(H, name='freq_slack_ATB', lb=0)
freq_slack_HSK = mdl.continuous_var_dict(H, name='freq_slack_HSK', lb=0)

mdl.minimize(
    mdl.sum(e['cost'] * x[e['src']['id'], e['dst']['id'], k] for e in E for k in K) +
    mdl.sum(vehicle_fixed_cost * z[k] for k in K) 
)

# mdl.minimize(
#     mdl.sum(z[k] for k in K) 
# )
#     # mdl.sum(freq_penalty * (freq_slack_ATB[h] + freq_slack_HSK[h]) for h in H)

for k in K:
    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E) <= bigM * z[k])
    mdl.add_constraint(z[k] <= mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E))

    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['src']['id'] == start_node_id) == z[k])
    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['dst']['id'] == end_node_id) == z[k])

    for node in V:
        i = node['id']
        if i != start_node_id and i != end_node_id:
            mdl.add_constraint(
                mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['src']['id'] == i) ==
                mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['dst']['id'] == i)
            )

for e in E:
    if e['N_bus'] == 1:
        mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for k in K) <= 1)

for k in K:
    mdl.add_constraint(T[k] == mdl.sum(e['cost'] * x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['N_bus'] == 1))
    mdl.add_constraint(T[k] >= MinUtilTime * z[k])
    mdl.add_constraint(T[k] <= MaxUtilTime * z[k])

for e in E:
    for k in K:
        i, j = e['src']['id'], e['dst']['id']
        cost = e['cost']
        mdl.add_constraint(arrival_time[k, j] >= arrival_time[k, i] + cost - bigM * (1 - x.get((i, j, k), 0)))
        mdl.add_constraint(arrival_time[k, j] <= arrival_time[k, i] + cost + bigM * (1 - x.get((i, j, k), 0)))

# for h in H:
#     mdl.add_constraint(
#         mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0)
#                 for k in K
#                 for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'ATB' and (e['src']['time'] // 60) == h)
#         + freq_slack_ATB[h] >= freq1[h]
#     )
#     mdl.add_constraint(
#         mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0)
#                 for k in K
#                 for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'HSK' and (e['src']['time'] // 60) == h)
#         + freq_slack_HSK[h] >= freq2[h]
#     )
for h in H:
    mdl.add_constraint(
        mdl.sum(
            x[e['src']['id'], e['dst']['id'], k]
            for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'ATB' and (e['src']['time'] // 60) == h
            for k in K
        ) >= freq1[h]
    )
    mdl.add_constraint(
        mdl.sum(
            x[e['src']['id'], e['dst']['id'], k]
            for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'HSK' and (e['src']['time'] // 60) == h
            for k in K
        ) >= freq2[h]
    )
solution = mdl.solve(log_output=True)

if solution:
    print("Objective:", solution.objective_value)
    used_vehicles = [k for k in K if z[k].solution_value > 0.5]
    print(f"Number of vehicles used: {len(used_vehicles)}\n")

    for k in used_vehicles:
        print(f"Schedule for Vehicle {k + 1}: Utilization time = {T[k].solution_value:.2f}")
        current_node = start_node_id
        while current_node != end_node_id:
            next_arcs = [e for e in E if e['src']['id'] == current_node and x.get((e['src']['id'], e['dst']['id'], k), 0).solution_value > 0.5]
            if not next_arcs:
                print("  ERROR: Route incomplete or disconnected.")
                break
            arc = next_arcs[0]
            src, dst = arc['src'], arc['dst']
            src_h, src_m = divmod(int(src['time']), 60)
            dst_h, dst_m = divmod(int(dst['time']), 60)
            print(f"  ({src['loc']} at {src_h:02d}:{src_m:02d}) --> ({dst['loc']} at {dst_h:02d}:{dst_m:02d}), cost={arc['cost']}")
            current_node = dst['id']
        print()
else:
    print("No feasible solution found.")
# Out:
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 2, 'dst_loc': 'ATB', 'dst_time': 1020, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 5, 'dst_loc': 'HSK', 'dst_time': 1020, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 3, 'dst_loc': 'ATB', 'dst_time': 1040, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 6, 'dst_loc': 'HSK', 'dst_time': 1040, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 4, 'dst_loc': 'ATB', 'dst_time': 1060, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 7, 'dst_loc': 'HSK', 'dst_time': 1060, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 8, 'dst_loc': 'ATB', 'dst_time': 1080, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 12, 'dst_loc': 'HSK', 'dst_time': 1080, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 9, 'dst_loc': 'ATB', 'dst_time': 1095, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 13, 'dst_loc': 'HSK', 'dst_time': 1095, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 10, 'dst_loc': 'ATB', 'dst_time': 1110, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 14, 'dst_loc': 'HSK', 'dst_time': 1110, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 11, 'dst_loc': 'ATB', 'dst_time': 1125, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 15, 'dst_loc': 'HSK', 'dst_time': 1125, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 16, 'dst_loc': 'ATB', 'dst_time': 1140, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 21, 'dst_loc': 'HSK', 'dst_time': 1140, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 17, 'dst_loc': 'ATB', 'dst_time': 1152, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 22, 'dst_loc': 'HSK', 'dst_time': 1152, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 18, 'dst_loc': 'ATB', 'dst_time': 1164, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 23, 'dst_loc': 'HSK', 'dst_time': 1164, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 19, 'dst_loc': 'ATB', 'dst_time': 1176, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 24, 'dst_loc': 'HSK', 'dst_time': 1176, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 20, 'dst_loc': 'ATB', 'dst_time': 1188, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 25, 'dst_loc': 'HSK', 'dst_time': 1188, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 26, 'dst_loc': 'ATB', 'dst_time': 1200, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 28, 'dst_loc': 'HSK', 'dst_time': 1200, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 27, 'dst_loc': 'ATB', 'dst_time': 1230, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 29, 'dst_loc': 'HSK', 'dst_time': 1230, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 30, 'dst_loc': 'ATB', 'dst_time': 1260, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 31, 'dst_loc': 'HSK', 'dst_time': 1260, 'cost': 10, 'N_bus': 150}
# {'src_id': 2, 'src_loc': 'ATB', 'src_time': 1020, 'dst_id': 33, 'dst_loc': 'HSK', 'dst_time': 1130, 'cost': 110, 'N_bus': 1}
# {'src_id': 33, 'src_loc': 'HSK', 'src_time': 1130, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 5, 'src_loc': 'HSK', 'src_time': 1020, 'dst_id': 34, 'dst_loc': 'ATB', 'dst_time': 1130, 'cost': 110, 'N_bus': 1}
# {'src_id': 34, 'src_loc': 'ATB', 'src_time': 1130, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 3, 'src_loc': 'ATB', 'src_time': 1040, 'dst_id': 35, 'dst_loc': 'HSK', 'dst_time': 1150, 'cost': 110, 'N_bus': 1}
# {'src_id': 35, 'src_loc': 'HSK', 'src_time': 1150, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 6, 'src_loc': 'HSK', 'src_time': 1040, 'dst_id': 36, 'dst_loc': 'ATB', 'dst_time': 1150, 'cost': 110, 'N_bus': 1}
# {'src_id': 36, 'src_loc': 'ATB', 'src_time': 1150, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 4, 'src_loc': 'ATB', 'src_time': 1060, 'dst_id': 37, 'dst_loc': 'HSK', 'dst_time': 1170, 'cost': 110, 'N_bus': 1}
# {'src_id': 37, 'src_loc': 'HSK', 'src_time': 1170, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 7, 'src_loc': 'HSK', 'src_time': 1060, 'dst_id': 38, 'dst_loc': 'ATB', 'dst_time': 1170, 'cost': 110, 'N_bus': 1}
# {'src_id': 38, 'src_loc': 'ATB', 'src_time': 1170, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 8, 'src_loc': 'ATB', 'src_time': 1080, 'dst_id': 39, 'dst_loc': 'HSK', 'dst_time': 1190, 'cost': 110, 'N_bus': 1}
# {'src_id': 39, 'src_loc': 'HSK', 'src_time': 1190, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 12, 'src_loc': 'HSK', 'src_time': 1080, 'dst_id': 40, 'dst_loc': 'ATB', 'dst_time': 1190, 'cost': 110, 'N_bus': 1}
# {'src_id': 40, 'src_loc': 'ATB', 'src_time': 1190, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 9, 'src_loc': 'ATB', 'src_time': 1095, 'dst_id': 41, 'dst_loc': 'HSK', 'dst_time': 1205, 'cost': 110, 'N_bus': 1}
# {'src_id': 41, 'src_loc': 'HSK', 'src_time': 1205, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 13, 'src_loc': 'HSK', 'src_time': 1095, 'dst_id': 42, 'dst_loc': 'ATB', 'dst_time': 1205, 'cost': 110, 'N_bus': 1}
# {'src_id': 42, 'src_loc': 'ATB', 'src_time': 1205, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 10, 'src_loc': 'ATB', 'src_time': 1110, 'dst_id': 43, 'dst_loc': 'HSK', 'dst_time': 1220, 'cost': 110, 'N_bus': 1}
# {'src_id': 43, 'src_loc': 'HSK', 'src_time': 1220, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 14, 'src_loc': 'HSK', 'src_time': 1110, 'dst_id': 44, 'dst_loc': 'ATB', 'dst_time': 1220, 'cost': 110, 'N_bus': 1}
# {'src_id': 44, 'src_loc': 'ATB', 'src_time': 1220, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 11, 'src_loc': 'ATB', 'src_time': 1125, 'dst_id': 45, 'dst_loc': 'HSK', 'dst_time': 1235, 'cost': 110, 'N_bus': 1}
# {'src_id': 45, 'src_loc': 'HSK', 'src_time': 1235, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 15, 'src_loc': 'HSK', 'src_time': 1125, 'dst_id': 46, 'dst_loc': 'ATB', 'dst_time': 1235, 'cost': 110, 'N_bus': 1}
# {'src_id': 46, 'src_loc': 'ATB', 'src_time': 1235, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 16, 'src_loc': 'ATB', 'src_time': 1140, 'dst_id': 47, 'dst_loc': 'HSK', 'dst_time': 1250, 'cost': 110, 'N_bus': 1}
# {'src_id': 47, 'src_loc': 'HSK', 'src_time': 1250, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 21, 'src_loc': 'HSK', 'src_time': 1140, 'dst_id': 48, 'dst_loc': 'ATB', 'dst_time': 1250, 'cost': 110, 'N_bus': 1}
# {'src_id': 48, 'src_loc': 'ATB', 'src_time': 1250, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 17, 'src_loc': 'ATB', 'src_time': 1152, 'dst_id': 49, 'dst_loc': 'HSK', 'dst_time': 1262, 'cost': 110, 'N_bus': 1}
# {'src_id': 49, 'src_loc': 'HSK', 'src_time': 1262, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 22, 'src_loc': 'HSK', 'src_time': 1152, 'dst_id': 50, 'dst_loc': 'ATB', 'dst_time': 1262, 'cost': 110, 'N_bus': 1}
# {'src_id': 50, 'src_loc': 'ATB', 'src_time': 1262, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 18, 'src_loc': 'ATB', 'src_time': 1164, 'dst_id': 51, 'dst_loc': 'HSK', 'dst_time': 1274, 'cost': 110, 'N_bus': 1}
# {'src_id': 51, 'src_loc': 'HSK', 'src_time': 1274, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 23, 'src_loc': 'HSK', 'src_time': 1164, 'dst_id': 52, 'dst_loc': 'ATB', 'dst_time': 1274, 'cost': 110, 'N_bus': 1}
# {'src_id': 52, 'src_loc': 'ATB', 'src_time': 1274, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 19, 'src_loc': 'ATB', 'src_time': 1176, 'dst_id': 53, 'dst_loc': 'HSK', 'dst_time': 1286, 'cost': 110, 'N_bus': 1}
# {'src_id': 53, 'src_loc': 'HSK', 'src_time': 1286, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 24, 'src_loc': 'HSK', 'src_time': 1176, 'dst_id': 54, 'dst_loc': 'ATB', 'dst_time': 1286, 'cost': 110, 'N_bus': 1}
# {'src_id': 54, 'src_loc': 'ATB', 'src_time': 1286, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 20, 'src_loc': 'ATB', 'src_time': 1188, 'dst_id': 55, 'dst_loc': 'HSK', 'dst_time': 1298, 'cost': 110, 'N_bus': 1}
# {'src_id': 55, 'src_loc': 'HSK', 'src_time': 1298, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 25, 'src_loc': 'HSK', 'src_time': 1188, 'dst_id': 56, 'dst_loc': 'ATB', 'dst_time': 1298, 'cost': 110, 'N_bus': 1}
# {'src_id': 56, 'src_loc': 'ATB', 'src_time': 1298, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 26, 'src_loc': 'ATB', 'src_time': 1200, 'dst_id': 57, 'dst_loc': 'HSK', 'dst_time': 1310, 'cost': 110, 'N_bus': 1}
# {'src_id': 57, 'src_loc': 'HSK', 'src_time': 1310, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 28, 'src_loc': 'HSK', 'src_time': 1200, 'dst_id': 58, 'dst_loc': 'ATB', 'dst_time': 1310, 'cost': 110, 'N_bus': 1}
# {'src_id': 58, 'src_loc': 'ATB', 'src_time': 1310, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 27, 'src_loc': 'ATB', 'src_time': 1230, 'dst_id': 59, 'dst_loc': 'HSK', 'dst_time': 1340, 'cost': 110, 'N_bus': 1}
# {'src_id': 59, 'src_loc': 'HSK', 'src_time': 1340, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 29, 'src_loc': 'HSK', 'src_time': 1230, 'dst_id': 60, 'dst_loc': 'ATB', 'dst_time': 1340, 'cost': 110, 'N_bus': 1}
# {'src_id': 60, 'src_loc': 'ATB', 'src_time': 1340, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 30, 'src_loc': 'ATB', 'src_time': 1260, 'dst_id': 61, 'dst_loc': 'HSK', 'dst_time': 1370, 'cost': 110, 'N_bus': 1}
# {'src_id': 61, 'src_loc': 'HSK', 'src_time': 1370, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 31, 'src_loc': 'HSK', 'src_time': 1260, 'dst_id': 62, 'dst_loc': 'ATB', 'dst_time': 1370, 'cost': 110, 'N_bus': 1}
# {'src_id': 62, 'src_loc': 'ATB', 'src_time': 1370, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 2, 'src_loc': 'ATB', 'src_time': 1020, 'dst_id': 3, 'dst_loc': 'ATB', 'dst_time': 1040, 'cost': 200, 'N_bus': 150}
# {'src_id': 3, 'src_loc': 'ATB', 'src_time': 1040, 'dst_id': 4, 'dst_loc': 'ATB', 'dst_time': 1060, 'cost': 200, 'N_bus': 150}
# {'src_id': 4, 'src_loc': 'ATB', 'src_time': 1060, 'dst_id': 8, 'dst_loc': 'ATB', 'dst_time': 1080, 'cost': 200, 'N_bus': 150}
# {'src_id': 8, 'src_loc': 'ATB', 'src_time': 1080, 'dst_id': 9, 'dst_loc': 'ATB', 'dst_time': 1095, 'cost': 200, 'N_bus': 150}
# {'src_id': 9, 'src_loc': 'ATB', 'src_time': 1095, 'dst_id': 10, 'dst_loc': 'ATB', 'dst_time': 1110, 'cost': 200, 'N_bus': 150}
# {'src_id': 10, 'src_loc': 'ATB', 'src_time': 1110, 'dst_id': 11, 'dst_loc': 'ATB', 'dst_time': 1125, 'cost': 200, 'N_bus': 150}
# {'src_id': 11, 'src_loc': 'ATB', 'src_time': 1125, 'dst_id': 34, 'dst_loc': 'ATB', 'dst_time': 1130, 'cost': 200, 'N_bus': 150}
# {'src_id': 34, 'src_loc': 'ATB', 'src_time': 1130, 'dst_id': 16, 'dst_loc': 'ATB', 'dst_time': 1140, 'cost': 200, 'N_bus': 150}
# {'src_id': 16, 'src_loc': 'ATB', 'src_time': 1140, 'dst_id': 36, 'dst_loc': 'ATB', 'dst_time': 1150, 'cost': 200, 'N_bus': 150}
# {'src_id': 36, 'src_loc': 'ATB', 'src_time': 1150, 'dst_id': 17, 'dst_loc': 'ATB', 'dst_time': 1152, 'cost': 200, 'N_bus': 150}
# {'src_id': 17, 'src_loc': 'ATB', 'src_time': 1152, 'dst_id': 18, 'dst_loc': 'ATB', 'dst_time': 1164, 'cost': 200, 'N_bus': 150}
# {'src_id': 18, 'src_loc': 'ATB', 'src_time': 1164, 'dst_id': 38, 'dst_loc': 'ATB', 'dst_time': 1170, 'cost': 200, 'N_bus': 150}
# {'src_id': 38, 'src_loc': 'ATB', 'src_time': 1170, 'dst_id': 19, 'dst_loc': 'ATB', 'dst_time': 1176, 'cost': 200, 'N_bus': 150}
# {'src_id': 19, 'src_loc': 'ATB', 'src_time': 1176, 'dst_id': 20, 'dst_loc': 'ATB', 'dst_time': 1188, 'cost': 200, 'N_bus': 150}
# {'src_id': 20, 'src_loc': 'ATB', 'src_time': 1188, 'dst_id': 40, 'dst_loc': 'ATB', 'dst_time': 1190, 'cost': 200, 'N_bus': 150}
# {'src_id': 40, 'src_loc': 'ATB', 'src_time': 1190, 'dst_id': 26, 'dst_loc': 'ATB', 'dst_time': 1200, 'cost': 200, 'N_bus': 150}
# {'src_id': 26, 'src_loc': 'ATB', 'src_time': 1200, 'dst_id': 42, 'dst_loc': 'ATB', 'dst_time': 1205, 'cost': 200, 'N_bus': 150}
# {'src_id': 42, 'src_loc': 'ATB', 'src_time': 1205, 'dst_id': 44, 'dst_loc': 'ATB', 'dst_time': 1220, 'cost': 200, 'N_bus': 150}
# {'src_id': 44, 'src_loc': 'ATB', 'src_time': 1220, 'dst_id': 27, 'dst_loc': 'ATB', 'dst_time': 1230, 'cost': 200, 'N_bus': 150}
# {'src_id': 27, 'src_loc': 'ATB', 'src_time': 1230, 'dst_id': 46, 'dst_loc': 'ATB', 'dst_time': 1235, 'cost': 200, 'N_bus': 150}
# {'src_id': 46, 'src_loc': 'ATB', 'src_time': 1235, 'dst_id': 48, 'dst_loc': 'ATB', 'dst_time': 1250, 'cost': 200, 'N_bus': 150}
# {'src_id': 48, 'src_loc': 'ATB', 'src_time': 1250, 'dst_id': 30, 'dst_loc': 'ATB', 'dst_time': 1260, 'cost': 200, 'N_bus': 150}
# {'src_id': 30, 'src_loc': 'ATB', 'src_time': 1260, 'dst_id': 50, 'dst_loc': 'ATB', 'dst_time': 1262, 'cost': 200, 'N_bus': 150}
# {'src_id': 50, 'src_loc': 'ATB', 'src_time': 1262, 'dst_id': 52, 'dst_loc': 'ATB', 'dst_time': 1274, 'cost': 200, 'N_bus': 150}
# {'src_id': 52, 'src_loc': 'ATB', 'src_time': 1274, 'dst_id': 54, 'dst_loc': 'ATB', 'dst_time': 1286, 'cost': 200, 'N_bus': 150}
# {'src_id': 54, 'src_loc': 'ATB', 'src_time': 1286, 'dst_id': 56, 'dst_loc': 'ATB', 'dst_time': 1298, 'cost': 200, 'N_bus': 150}
# {'src_id': 56, 'src_loc': 'ATB', 'src_time': 1298, 'dst_id': 58, 'dst_loc': 'ATB', 'dst_time': 1310, 'cost': 200, 'N_bus': 150}
# {'src_id': 58, 'src_loc': 'ATB', 'src_time': 1310, 'dst_id': 60, 'dst_loc': 'ATB', 'dst_time': 1340, 'cost': 200, 'N_bus': 150}
# {'src_id': 60, 'src_loc': 'ATB', 'src_time': 1340, 'dst_id': 62, 'dst_loc': 'ATB', 'dst_time': 1370, 'cost': 200, 'N_bus': 150}
# {'src_id': 5, 'src_loc': 'HSK', 'src_time': 1020, 'dst_id': 6, 'dst_loc': 'HSK', 'dst_time': 1040, 'cost': 200, 'N_bus': 150}
# {'src_id': 6, 'src_loc': 'HSK', 'src_time': 1040, 'dst_id': 7, 'dst_loc': 'HSK', 'dst_time': 1060, 'cost': 200, 'N_bus': 150}
# {'src_id': 7, 'src_loc': 'HSK', 'src_time': 1060, 'dst_id': 12, 'dst_loc': 'HSK', 'dst_time': 1080, 'cost': 200, 'N_bus': 150}
# {'src_id': 12, 'src_loc': 'HSK', 'src_time': 1080, 'dst_id': 13, 'dst_loc': 'HSK', 'dst_time': 1095, 'cost': 200, 'N_bus': 150}
# {'src_id': 13, 'src_loc': 'HSK', 'src_time': 1095, 'dst_id': 14, 'dst_loc': 'HSK', 'dst_time': 1110, 'cost': 200, 'N_bus': 150}
# {'src_id': 14, 'src_loc': 'HSK', 'src_time': 1110, 'dst_id': 15, 'dst_loc': 'HSK', 'dst_time': 1125, 'cost': 200, 'N_bus': 150}
# {'src_id': 15, 'src_loc': 'HSK', 'src_time': 1125, 'dst_id': 33, 'dst_loc': 'HSK', 'dst_time': 1130, 'cost': 200, 'N_bus': 150}
# {'src_id': 33, 'src_loc': 'HSK', 'src_time': 1130, 'dst_id': 21, 'dst_loc': 'HSK', 'dst_time': 1140, 'cost': 200, 'N_bus': 150}
# {'src_id': 21, 'src_loc': 'HSK', 'src_time': 1140, 'dst_id': 35, 'dst_loc': 'HSK', 'dst_time': 1150, 'cost': 200, 'N_bus': 150}
# {'src_id': 35, 'src_loc': 'HSK', 'src_time': 1150, 'dst_id': 22, 'dst_loc': 'HSK', 'dst_time': 1152, 'cost': 200, 'N_bus': 150}
# {'src_id': 22, 'src_loc': 'HSK', 'src_time': 1152, 'dst_id': 23, 'dst_loc': 'HSK', 'dst_time': 1164, 'cost': 200, 'N_bus': 150}
# {'src_id': 23, 'src_loc': 'HSK', 'src_time': 1164, 'dst_id': 37, 'dst_loc': 'HSK', 'dst_time': 1170, 'cost': 200, 'N_bus': 150}
# {'src_id': 37, 'src_loc': 'HSK', 'src_time': 1170, 'dst_id': 24, 'dst_loc': 'HSK', 'dst_time': 1176, 'cost': 200, 'N_bus': 150}
# {'src_id': 24, 'src_loc': 'HSK', 'src_time': 1176, 'dst_id': 25, 'dst_loc': 'HSK', 'dst_time': 1188, 'cost': 200, 'N_bus': 150}
# {'src_id': 25, 'src_loc': 'HSK', 'src_time': 1188, 'dst_id': 39, 'dst_loc': 'HSK', 'dst_time': 1190, 'cost': 200, 'N_bus': 150}
# {'src_id': 39, 'src_loc': 'HSK', 'src_time': 1190, 'dst_id': 28, 'dst_loc': 'HSK', 'dst_time': 1200, 'cost': 200, 'N_bus': 150}
# {'src_id': 28, 'src_loc': 'HSK', 'src_time': 1200, 'dst_id': 41, 'dst_loc': 'HSK', 'dst_time': 1205, 'cost': 200, 'N_bus': 150}
# {'src_id': 41, 'src_loc': 'HSK', 'src_time': 1205, 'dst_id': 43, 'dst_loc': 'HSK', 'dst_time': 1220, 'cost': 200, 'N_bus': 150}
# {'src_id': 43, 'src_loc': 'HSK', 'src_time': 1220, 'dst_id': 29, 'dst_loc': 'HSK', 'dst_time': 1230, 'cost': 200, 'N_bus': 150}
# {'src_id': 29, 'src_loc': 'HSK', 'src_time': 1230, 'dst_id': 45, 'dst_loc': 'HSK', 'dst_time': 1235, 'cost': 200, 'N_bus': 150}
# {'src_id': 45, 'src_loc': 'HSK', 'src_time': 1235, 'dst_id': 47, 'dst_loc': 'HSK', 'dst_time': 1250, 'cost': 200, 'N_bus': 150}
# {'src_id': 47, 'src_loc': 'HSK', 'src_time': 1250, 'dst_id': 31, 'dst_loc': 'HSK', 'dst_time': 1260, 'cost': 200, 'N_bus': 150}
# {'src_id': 31, 'src_loc': 'HSK', 'src_time': 1260, 'dst_id': 49, 'dst_loc': 'HSK', 'dst_time': 1262, 'cost': 200, 'N_bus': 150}
# {'src_id': 49, 'src_loc': 'HSK', 'src_time': 1262, 'dst_id': 51, 'dst_loc': 'HSK', 'dst_time': 1274, 'cost': 200, 'N_bus': 150}
# {'src_id': 51, 'src_loc': 'HSK', 'src_time': 1274, 'dst_id': 53, 'dst_loc': 'HSK', 'dst_time': 1286, 'cost': 200, 'N_bus': 150}
# {'src_id': 53, 'src_loc': 'HSK', 'src_time': 1286, 'dst_id': 55, 'dst_loc': 'HSK', 'dst_time': 1298, 'cost': 200, 'N_bus': 150}
# {'src_id': 55, 'src_loc': 'HSK', 'src_time': 1298, 'dst_id': 57, 'dst_loc': 'HSK', 'dst_time': 1310, 'cost': 200, 'N_bus': 150}
# {'src_id': 57, 'src_loc': 'HSK', 'src_time': 1310, 'dst_id': 59, 'dst_loc': 'HSK', 'dst_time': 1340, 'cost': 200, 'N_bus': 150}
# {'src_id': 59, 'src_loc': 'HSK', 'src_time': 1340, 'dst_id': 61, 'dst_loc': 'HSK', 'dst_time': 1370, 'cost': 200, 'N_bus': 150}
# {'src_id': 2, 'src_loc': 'ATB', 'src_time': 1020, 'dst_id': 21, 'dst_loc': 'HSK', 'dst_time': 1140, 'cost': 180, 'N_bus': 150}
# {'src_id': 5, 'src_loc': 'HSK', 'src_time': 1020, 'dst_id': 16, 'dst_loc': 'ATB', 'dst_time': 1140, 'cost': 180, 'N_bus': 150}
# {'src_id': 3, 'src_loc': 'ATB', 'src_time': 1040, 'dst_id': 22, 'dst_loc': 'HSK', 'dst_time': 1152, 'cost': 180, 'N_bus': 150}
# {'src_id': 6, 'src_loc': 'HSK', 'src_time': 1040, 'dst_id': 17, 'dst_loc': 'ATB', 'dst_time': 1152, 'cost': 180, 'N_bus': 150}
# {'src_id': 4, 'src_loc': 'ATB', 'src_time': 1060, 'dst_id': 24, 'dst_loc': 'HSK', 'dst_time': 1176, 'cost': 180, 'N_bus': 150}
# {'src_id': 7, 'src_loc': 'HSK', 'src_time': 1060, 'dst_id': 19, 'dst_loc': 'ATB', 'dst_time': 1176, 'cost': 180, 'N_bus': 150}
# {'src_id': 8, 'src_loc': 'ATB', 'src_time': 1080, 'dst_id': 28, 'dst_loc': 'HSK', 'dst_time': 1200, 'cost': 180, 'N_bus': 150}
# {'src_id': 12, 'src_loc': 'HSK', 'src_time': 1080, 'dst_id': 26, 'dst_loc': 'ATB', 'dst_time': 1200, 'cost': 180, 'N_bus': 150}
# {'src_id': 9, 'src_loc': 'ATB', 'src_time': 1095, 'dst_id': 43, 'dst_loc': 'HSK', 'dst_time': 1220, 'cost': 180, 'N_bus': 150}
# {'src_id': 13, 'src_loc': 'HSK', 'src_time': 1095, 'dst_id': 44, 'dst_loc': 'ATB', 'dst_time': 1220, 'cost': 180, 'N_bus': 150}
# {'src_id': 10, 'src_loc': 'ATB', 'src_time': 1110, 'dst_id': 29, 'dst_loc': 'HSK', 'dst_time': 1230, 'cost': 180, 'N_bus': 150}
# {'src_id': 14, 'src_loc': 'HSK', 'src_time': 1110, 'dst_id': 27, 'dst_loc': 'ATB', 'dst_time': 1230, 'cost': 180, 'N_bus': 150}
# {'src_id': 11, 'src_loc': 'ATB', 'src_time': 1125, 'dst_id': 47, 'dst_loc': 'HSK', 'dst_time': 1250, 'cost': 180, 'N_bus': 150}
# {'src_id': 15, 'src_loc': 'HSK', 'src_time': 1125, 'dst_id': 48, 'dst_loc': 'ATB', 'dst_time': 1250, 'cost': 180, 'N_bus': 150}
# {'src_id': 16, 'src_loc': 'ATB', 'src_time': 1140, 'dst_id': 31, 'dst_loc': 'HSK', 'dst_time': 1260, 'cost': 180, 'N_bus': 150}
# {'src_id': 21, 'src_loc': 'HSK', 'src_time': 1140, 'dst_id': 30, 'dst_loc': 'ATB', 'dst_time': 1260, 'cost': 180, 'N_bus': 150}
# {'src_id': 17, 'src_loc': 'ATB', 'src_time': 1152, 'dst_id': 51, 'dst_loc': 'HSK', 'dst_time': 1274, 'cost': 180, 'N_bus': 150}
# {'src_id': 22, 'src_loc': 'HSK', 'src_time': 1152, 'dst_id': 52, 'dst_loc': 'ATB', 'dst_time': 1274, 'cost': 180, 'N_bus': 150}
# {'src_id': 18, 'src_loc': 'ATB', 'src_time': 1164, 'dst_id': 53, 'dst_loc': 'HSK', 'dst_time': 1286, 'cost': 180, 'N_bus': 150}
# {'src_id': 23, 'src_loc': 'HSK', 'src_time': 1164, 'dst_id': 54, 'dst_loc': 'ATB', 'dst_time': 1286, 'cost': 180, 'N_bus': 150}
# {'src_id': 19, 'src_loc': 'ATB', 'src_time': 1176, 'dst_id': 55, 'dst_loc': 'HSK', 'dst_time': 1298, 'cost': 180, 'N_bus': 150}
# {'src_id': 24, 'src_loc': 'HSK', 'src_time': 1176, 'dst_id': 56, 'dst_loc': 'ATB', 'dst_time': 1298, 'cost': 180, 'N_bus': 150}
# {'src_id': 20, 'src_loc': 'ATB', 'src_time': 1188, 'dst_id': 57, 'dst_loc': 'HSK', 'dst_time': 1310, 'cost': 180, 'N_bus': 150}
# {'src_id': 25, 'src_loc': 'HSK', 'src_time': 1188, 'dst_id': 58, 'dst_loc': 'ATB', 'dst_time': 1310, 'cost': 180, 'N_bus': 150}
# {'src_id': 26, 'src_loc': 'ATB', 'src_time': 1200, 'dst_id': 59, 'dst_loc': 'HSK', 'dst_time': 1340, 'cost': 180, 'N_bus': 150}
# {'src_id': 28, 'src_loc': 'HSK', 'src_time': 1200, 'dst_id': 60, 'dst_loc': 'ATB', 'dst_time': 1340, 'cost': 180, 'N_bus': 150}
# {'src_id': 27, 'src_loc': 'ATB', 'src_time': 1230, 'dst_id': 61, 'dst_loc': 'HSK', 'dst_time': 1370, 'cost': 180, 'N_bus': 150}
# {'src_id': 29, 'src_loc': 'HSK', 'src_time': 1230, 'dst_id': 62, 'dst_loc': 'ATB', 'dst_time': 1370, 'cost': 180, 'N_bus': 150}
# {'src_id': 30, 'src_loc': 'ATB', 'src_time': 1260, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 180, 'N_bus': 150}
# {'src_id': 31, 'src_loc': 'HSK', 'src_time': 1260, 'dst_id': 32, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 180, 'N_bus': 150}
# {'src_id': 33, 'src_loc': 'HSK', 'src_time': 1130, 'dst_id': 48, 'dst_loc': 'ATB', 'dst_time': 1250, 'cost': 180, 'N_bus': 150}
# {'src_id': 34, 'src_loc': 'ATB', 'src_time': 1130, 'dst_id': 47, 'dst_loc': 'HSK', 'dst_time': 1250, 'cost': 180, 'N_bus': 150}
# {'src_id': 35, 'src_loc': 'HSK', 'src_time': 1150, 'dst_id': 50, 'dst_loc': 'ATB', 'dst_time': 1262, 'cost': 180, 'N_bus': 150}
# {'src_id': 36, 'src_loc': 'ATB', 'src_time': 1150, 'dst_id': 49, 'dst_loc': 'HSK', 'dst_time': 1262, 'cost': 180, 'N_bus': 150}
# {'src_id': 37, 'src_loc': 'HSK', 'src_time': 1170, 'dst_id': 54, 'dst_loc': 'ATB', 'dst_time': 1286, 'cost': 180, 'N_bus': 150}
# {'src_id': 38, 'src_loc': 'ATB', 'src_time': 1170, 'dst_id': 53, 'dst_loc': 'HSK', 'dst_time': 1286, 'cost': 180, 'N_bus': 150}
# {'src_id': 39, 'src_loc': 'HSK', 'src_time': 1190, 'dst_id': 58, 'dst_loc': 'ATB', 'dst_time': 1310, 'cost': 180, 'N_bus': 150}
# {'src_id': 40, 'src_loc': 'ATB', 'src_time': 1190, 'dst_id': 57, 'dst_loc': 'HSK', 'dst_time': 1310, 'cost': 180, 'N_bus': 150}
# {'src_id': 41, 'src_loc': 'HSK', 'src_time': 1205, 'dst_id': 60, 'dst_loc': 'ATB', 'dst_time': 1340, 'cost': 180, 'N_bus': 150}
# {'src_id': 42, 'src_loc': 'ATB', 'src_time': 1205, 'dst_id': 59, 'dst_loc': 'HSK', 'dst_time': 1340, 'cost': 180, 'N_bus': 150}
# {'src_id': 43, 'src_loc': 'HSK', 'src_time': 1220, 'dst_id': 60, 'dst_loc': 'ATB', 'dst_time': 1340, 'cost': 180, 'N_bus': 150}
# {'src_id': 44, 'src_loc': 'ATB', 'src_time': 1220, 'dst_id': 59, 'dst_loc': 'HSK', 'dst_time': 1340, 'cost': 180, 'N_bus': 150}
# {'src_id': 45, 'src_loc': 'HSK', 'src_time': 1235, 'dst_id': 62, 'dst_loc': 'ATB', 'dst_time': 1370, 'cost': 180, 'N_bus': 150}
# {'src_id': 46, 'src_loc': 'ATB', 'src_time': 1235, 'dst_id': 61, 'dst_loc': 'HSK', 'dst_time': 1370, 'cost': 180, 'N_bus': 150}
# {'src_id': 47, 'src_loc': 'HSK', 'src_time': 1250, 'dst_id': 62, 'dst_loc': 'ATB', 'dst_time': 1370, 'cost': 180, 'N_bus': 150}
# {'src_id': 48, 'src_loc': 'ATB', 'src_time': 1250, 'dst_id': 61, 'dst_loc': 'HSK', 'dst_time': 1370, 'cost': 180, 'N_bus': 150}
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_LPMethod                                3
# Tried aggregator 1 time.
# MIP Presolve eliminated 190 rows and 48 columns.
# MIP Presolve modified 105450 coefficients.
# Reduced MIP has 68138 rows, 38700 columns, and 259800 nonzeros.
# Reduced MIP has 29250 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.70 sec. (334.26 ticks)
# Probing fixed 1200 vars, tightened 0 bounds.
# Probing time = 0.55 sec. (30.52 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated 1800 rows and 1200 columns.
# MIP Presolve modified 1200 coefficients.
# Reduced MIP has 66338 rows, 37500 columns, and 250800 nonzeros.
# Reduced MIP has 28050 binaries, 150 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.78 sec. (280.12 ticks)
# Probing time = 9.97 sec. (16.55 ticks)
# Clique table members: 157989.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 32 threads.
# Root relaxation solution time = 1.03 sec. (553.51 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0    24600.0000   234                  24600.0000        9
#       0     0    24600.0000   938                   Cuts: 533     2506
#       0     0    24600.0000   825                  Cuts: 1366     4778
#       0     0    24600.0000   753                  Cuts: 1267     8076
#       0     0    24600.0000   499                  Cuts: 1462    11282
#       0     0        cutoff                                      12002
# Elapsed time = 56.27 sec. (14635.32 ticks, tree = 0.01 MB, solutions = 0)
#
# Cover cuts applied:  79
# Implied bound cuts applied:  2306
# Flow cuts applied:  927
# Mixed integer rounding cuts applied:  1331
# Zero-half cuts applied:  5
# Gomory fractional cuts applied:  6
#
# Root node processing (before b&c):
#   Real time             =   56.33 sec. (14636.50 ticks)
# Parallel b&c, 32 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =   56.33 sec. (14636.50 ticks)
# No feasible solution found.

# %%
# E = cleaned_E
from docplex.mp.model import Model
from datetime import timedelta

# --- CONSTANTS ---
HOURS = 24
MINUTES_IN_DAY = 1440
MinUtilTime = 150
MinUtilTime_2 = 150
MaxUtilTime = 1000

vehicle_fixed_cost = 1000
freq_penalty = 1000

nvehicle = 150
K = range(nvehicle)
H = range(HOURS)

bigM = 1440

freq1 = [0]*17 + [3, 4, 5, 4, 5, 0, 0]  # ATB
freq2 = [0]*17 + [3, 4, 5, 4, 5, 0, 0]  # HSK
# freq1 = [0, 0, 0, 0, 4, 4, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 0, 0, 1, 1, 2, 2, 0, 0]
# freq2 = [0, 0, 0, 0, 4, 4, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 0, 0, 1, 1, 2, 2, 0, 0]

arc_data = {
    ("X", "X"): (0, 150),
    ("X", "HSK"): (10, 150),
    ("X", "ATB"): (40, 150),
    ("HSK", "HSK"): (200, 150),
    ("ATB", "ATB"): (200, 150),
    ("HSK", "ATB"): (110, 1),
    ("ATB", "HSK"): (110, 1),
    ("HSK", "X"): (10, 150),
    ("ATB", "X"): (40, 150)
}

transitions = {"ATB": "HSK", "HSK": "ATB"}
travel_time = {("ATB", "HSK"): 110, ("HSK", "ATB"): 110}

# --- NODES ---
nodes = []
node_id = 1
nodes.append({'id': node_id, 'time': 0, 'loc': 'X'})
start_node_id = node_id
node_id += 1

for hour in H:
    for i in range(freq1[hour]):
        time_val = hour * 60 + (i * 60 // max(freq1[hour], 1))
        nodes.append({'id': node_id, 'time': time_val, 'loc': 'ATB'})
        node_id += 1
    for i in range(freq2[hour]):
        time_val = hour * 60 + (i * 60 // max(freq2[hour], 1))
        nodes.append({'id': node_id, 'time': time_val, 'loc': 'HSK'})
        node_id += 1

nodes.append({'id': node_id, 'time': MINUTES_IN_DAY, 'loc': 'X'})
end_node_id = node_id
node_id += 1

nodes.sort(key=lambda x: x['time'])
V = nodes.copy()

# --- INITIAL ARCS ---
E = []
synthetic_id = node_id
synthetic_nodes = []

for node in nodes:
    loc = node['loc']
    dst_time = node['time']
    if loc in ['ATB', 'HSK']:
        cost, N_bus = arc_data[('X', loc)]
        if dst_time >= cost:
            E.append({
                'src': {'id': start_node_id, 'time': 0, 'loc': 'X'},
                'dst': {'id': node['id'], 'time': dst_time, 'loc': loc},
                'cost': cost,
                'N_bus': N_bus
            })

for node in nodes:
    loc = node['loc']
    time = node['time']
    src_id = node['id']

    if loc not in transitions:
        continue

    total_time = 0
    curr_loc = loc
    curr_time = time
    curr_src_id = src_id

    while total_time + travel_time[(curr_loc, transitions[curr_loc])] <= MinUtilTime_2:
        next_loc = transitions[curr_loc]
        cost = travel_time[(curr_loc, next_loc)]
        next_time = curr_time + cost

        if next_time > MINUTES_IN_DAY:
            break

        dst = {'id': synthetic_id, 'time': next_time, 'loc': next_loc}
        synthetic_nodes.append(dst)

        E.append({
            'src': {'id': curr_src_id, 'time': curr_time, 'loc': curr_loc},
            'dst': dst,
            'cost': cost,
            'N_bus': 1
        })

        curr_src_id = synthetic_id
        curr_time = next_time
        curr_loc = next_loc
        synthetic_id += 1
        total_time += cost

    if curr_time <= MINUTES_IN_DAY:
        cost_to_X, N_bus_to_X = arc_data[(curr_loc, 'X')]
        E.append({
            'src': {'id': curr_src_id, 'time': curr_time, 'loc': curr_loc},
            'dst': {'id': end_node_id, 'time': MINUTES_IN_DAY, 'loc': 'X'},
            'cost': cost_to_X,
            'N_bus': N_bus_to_X
        })

V.extend(synthetic_nodes)

for node in V:
    node['hhmm'] = str(timedelta(minutes=node['time']))[:-3]

# --- ADD WAITING AND DEADHEADING ARCS ---
MAX_WAIT = 60
augmented_E = E.copy()
unique_keys = set()

# Add existing arcs to unique_keys to avoid duplication later
for e in E:
    arc_key = (
        e['src']['id'], e['src']['time'], e['src']['loc'],
        e['dst']['id'], e['dst']['time'], e['dst']['loc'],
        e['cost'], e['N_bus']
    )
    unique_keys.add(arc_key)

# Waiting arcs
# for src in V:
#     for dst in V:
#         if src['id'] == dst['id']:
#             continue
#         time_diff = dst['time'] - src['time']
#         if src['loc'] == dst['loc'] and 0 < time_diff <= MAX_WAIT:
#             arc_key = (
#                 src['id'], src['time'], src['loc'],
#                 dst['id'], dst['time'], dst['loc'],
#                 200, 150
#             )
#             if arc_key not in unique_keys:
#                 unique_keys.add(arc_key)
#                 augmented_E.append({
#                     'src': src,
#                     'dst': dst,
#                     'cost': 200,
#                     'N_bus': 150
#                 })
# Sort nodes by location and time to easily find next closest at same loc
from collections import defaultdict

# Group nodes by location
nodes_by_loc = defaultdict(list)
for node in V:
    nodes_by_loc[node['loc']].append(node)

# Sort nodes by time for each location
for loc in nodes_by_loc:
    nodes_by_loc[loc].sort(key=lambda n: n['time'])

# Create minimal waiting arcs (only to immediate next time at same loc)
for loc, nodes in nodes_by_loc.items():
    for i in range(len(nodes) - 1):
        src = nodes[i]
        dst = nodes[i + 1]

        time_diff = dst['time'] - src['time']
        if 0 < time_diff <= MAX_WAIT:
            arc_key = (
                src['id'], src['time'], src['loc'],
                dst['id'], dst['time'], dst['loc'],
                200, 150
            )
            if arc_key not in unique_keys:
                unique_keys.add(arc_key)
                augmented_E.append({
                    'src': src,
                    'dst': dst,
                    'cost': 200,
                    'N_bus': 150
                })


# Deadheading arcs
# for src in V:
#     for dst in V:
#         if src['id'] == dst['id'] or src['loc'] == dst['loc']:
#             continue

#         key = (src['loc'], dst['loc'])
#         if key not in arc_data:
#             continue

#         travel_t, cap = arc_data[key]
#         if dst['time'] > src['time'] + travel_t:
#             arc_key = (
#                 src['id'], src['time'], src['loc'],
#                 dst['id'], dst['time'], dst['loc'],
#                 travel_t, cap
#             )
#             if arc_key not in unique_keys:
#                 unique_keys.add(arc_key)
#                 augmented_E.append({
#                     'src': src,
#                     'dst': dst,
#                     'cost': 180,
#                     'N_bus': 150
#                 })
for src in V:
    best_arcs_by_dst_loc = {}
    
    for dst in V:
        if src['id'] == dst['id'] or src['loc'] == dst['loc']:
            continue

        key = (src['loc'], dst['loc'])
        if key not in arc_data:
            continue

        travel_t, cap = arc_data[key]

        if dst['time'] > src['time'] + travel_t:
            time_diff = dst['time'] - src['time'] - travel_t

            # Keep only the best arc (least time diff) per dst location
            if dst['loc'] not in best_arcs_by_dst_loc or time_diff < best_arcs_by_dst_loc[dst['loc']]['time_diff']:
                best_arcs_by_dst_loc[dst['loc']] = {
                    'dst': dst,
                    'travel_t': travel_t,
                    'cap': cap,
                    'time_diff': time_diff
                }

    # Now select the single best arc among all dst_locs (least time_diff)
    if best_arcs_by_dst_loc:
        # Find arc with minimal time_diff overall
        best_dst_loc = min(best_arcs_by_dst_loc, key=lambda loc: best_arcs_by_dst_loc[loc]['time_diff'])
        best = best_arcs_by_dst_loc[best_dst_loc]

        arc_key = (
            src['id'], src['time'], src['loc'],
            best['dst']['id'], best['dst']['time'], best['dst']['loc'],
            best['travel_t'], best['cap']
        )

        if arc_key not in unique_keys:
            unique_keys.add(arc_key)
            augmented_E.append({
                'src': src,
                'dst': best['dst'],
                'cost': 180,
                'N_bus': 150
            })
# depot_return_arcs = []
# X = 'X'  # Depot

# for e in augmented_E:
#     if e['src']['loc'] == X or e['dst']['loc'] == X:
#         continue  # Skip depot arcs

#     src = e['src']
#     dst = e['dst']
#     direct_cost = e['cost']
#     src_to_depot_key = (src['loc'], X)
#     depot_to_dst_key = (X, dst['loc'])

#     if src_to_depot_key in arc_data and depot_to_dst_key in arc_data:
#         src_to_depot_cost, _ = arc_data[src_to_depot_key]
#         depot_to_dst_cost, _ = arc_data[depot_to_dst_key]

#         time_to_depot = src_to_depot_cost
#         time_from_depot = depot_to_dst_cost
#         total_depot_time = time_to_depot + time_from_depot

#         if dst['time'] >= src['time'] + total_depot_time:
#             depot_total_cost = src_to_depot_cost + depot_to_dst_cost

#             if depot_total_cost < direct_cost:
#                 arc_key = (
#                     src['id'], src['time'], src['loc'],
#                     dst['id'], dst['time'], dst['loc'],
#                     depot_total_cost, e['N_bus']
#                 )
#                 if arc_key not in unique_keys:
#                     unique_keys.add(arc_key)
#                     depot_return_arcs.append({
#                         'src': src,
#                         'dst': dst,
#                         'cost': depot_total_cost,
#                         'N_bus': e['N_bus']
#                     })
#                 # Remove the direct expensive arc
#                 augmented_E.remove(e)

# augmented_E.extend(depot_return_arcs)


# Final cleaned arcs
E = augmented_E
# --- FINAL OUTPUT [unchanged] ---
for arc in E:
    print({
        'src_id': arc['src']['id'],
        'src_loc': arc['src']['loc'],
        'src_time': arc['src']['time'],
        'dst_id': arc['dst']['id'],
        'dst_loc': arc['dst']['loc'],
        'dst_time': arc['dst']['time'],
        'cost': arc['cost'],
        'N_bus': arc['N_bus']
    })
# --- MODEL ---
mdl = Model("VehicleScheduling")
mdl.context.cplex_parameters.lpmethod = 3

x = mdl.binary_var_dict(((e['src']['id'], e['dst']['id'], k) for e in E for k in K), name='x')
z = mdl.binary_var_dict(K, name='z')
T = mdl.continuous_var_dict(K, name='T', lb=0)

node_ids_in_arcs = set()
for e in E:
    node_ids_in_arcs.add(e['src']['id'])
    node_ids_in_arcs.add(e['dst']['id'])

arrival_time = mdl.continuous_var_dict(((k, nid) for k in K for nid in node_ids_in_arcs), name='arr', lb=0, ub=MINUTES_IN_DAY)
freq_slack_ATB = mdl.continuous_var_dict(H, name='freq_slack_ATB', lb=0)
freq_slack_HSK = mdl.continuous_var_dict(H, name='freq_slack_HSK', lb=0)

mdl.minimize(
    mdl.sum(e['cost'] * x[e['src']['id'], e['dst']['id'], k] for e in E for k in K) +
    mdl.sum(vehicle_fixed_cost * z[k] for k in K) 
)

# mdl.minimize(
#     mdl.sum(z[k] for k in K) 
# )
#     # mdl.sum(freq_penalty * (freq_slack_ATB[h] + freq_slack_HSK[h]) for h in H)

for k in K:
    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E) <= bigM * z[k])
    mdl.add_constraint(z[k] <= mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E))

    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['src']['id'] == start_node_id) == z[k])
    mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['dst']['id'] == end_node_id) == z[k])

    for node in V:
        i = node['id']
        if i != start_node_id and i != end_node_id:
            mdl.add_constraint(
                mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['src']['id'] == i) ==
                mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['dst']['id'] == i)
            )

for e in E:
    if e['N_bus'] == 1:
        mdl.add_constraint(mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0) for k in K) <= 1)

for k in K:
    mdl.add_constraint(T[k] == mdl.sum(e['cost'] * x.get((e['src']['id'], e['dst']['id'], k), 0) for e in E if e['N_bus'] == 1))
    mdl.add_constraint(T[k] >= MinUtilTime * z[k])
    mdl.add_constraint(T[k] <= MaxUtilTime * z[k])

for e in E:
    for k in K:
        i, j = e['src']['id'], e['dst']['id']
        cost = e['cost']
        mdl.add_constraint(arrival_time[k, j] >= arrival_time[k, i] + cost - bigM * (1 - x.get((i, j, k), 0)))
        mdl.add_constraint(arrival_time[k, j] <= arrival_time[k, i] + cost + bigM * (1 - x.get((i, j, k), 0)))

# for h in H:
#     mdl.add_constraint(
#         mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0)
#                 for k in K
#                 for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'ATB' and (e['src']['time'] // 60) == h)
#         + freq_slack_ATB[h] >= freq1[h]
#     )
#     mdl.add_constraint(
#         mdl.sum(x.get((e['src']['id'], e['dst']['id'], k), 0)
#                 for k in K
#                 for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'HSK' and (e['src']['time'] // 60) == h)
#         + freq_slack_HSK[h] >= freq2[h]
#     )
for h in H:
    mdl.add_constraint(
        mdl.sum(
            x[e['src']['id'], e['dst']['id'], k]
            for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'ATB' and (e['src']['time'] // 60) == h
            for k in K
        ) >= freq1[h]
    )
    mdl.add_constraint(
        mdl.sum(
            x[e['src']['id'], e['dst']['id'], k]
            for e in E if e['N_bus'] == 1 and e['src']['loc'] == 'HSK' and (e['src']['time'] // 60) == h
            for k in K
        ) >= freq2[h]
    )
solution = mdl.solve(log_output=True)

if solution:
    print("Objective:", solution.objective_value)
    used_vehicles = [k for k in K if z[k].solution_value > 0.5]
    print(f"Number of vehicles used: {len(used_vehicles)}\n")

    for k in used_vehicles:
        print(f"Schedule for Vehicle {k + 1}: Utilization time = {T[k].solution_value:.2f}")
        current_node = start_node_id
        while current_node != end_node_id:
            next_arcs = [e for e in E if e['src']['id'] == current_node and x.get((e['src']['id'], e['dst']['id'], k), 0).solution_value > 0.5]
            if not next_arcs:
                print("  ERROR: Route incomplete or disconnected.")
                break
            arc = next_arcs[0]
            src, dst = arc['src'], arc['dst']
            src_h, src_m = divmod(int(src['time']), 60)
            dst_h, dst_m = divmod(int(dst['time']), 60)
            print(f"  ({src['loc']} at {src_h:02d}:{src_m:02d}) --> ({dst['loc']} at {dst_h:02d}:{dst_m:02d}), cost={arc['cost']}")
            current_node = dst['id']
        print()
else:
    print("No feasible solution found.")
# Out:
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 2, 'dst_loc': 'ATB', 'dst_time': 1020, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 5, 'dst_loc': 'HSK', 'dst_time': 1020, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 3, 'dst_loc': 'ATB', 'dst_time': 1040, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 6, 'dst_loc': 'HSK', 'dst_time': 1040, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 4, 'dst_loc': 'ATB', 'dst_time': 1060, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 7, 'dst_loc': 'HSK', 'dst_time': 1060, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 8, 'dst_loc': 'ATB', 'dst_time': 1080, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 12, 'dst_loc': 'HSK', 'dst_time': 1080, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 9, 'dst_loc': 'ATB', 'dst_time': 1095, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 13, 'dst_loc': 'HSK', 'dst_time': 1095, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 10, 'dst_loc': 'ATB', 'dst_time': 1110, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 14, 'dst_loc': 'HSK', 'dst_time': 1110, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 11, 'dst_loc': 'ATB', 'dst_time': 1125, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 15, 'dst_loc': 'HSK', 'dst_time': 1125, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 16, 'dst_loc': 'ATB', 'dst_time': 1140, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 21, 'dst_loc': 'HSK', 'dst_time': 1140, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 17, 'dst_loc': 'ATB', 'dst_time': 1152, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 22, 'dst_loc': 'HSK', 'dst_time': 1152, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 18, 'dst_loc': 'ATB', 'dst_time': 1164, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 23, 'dst_loc': 'HSK', 'dst_time': 1164, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 19, 'dst_loc': 'ATB', 'dst_time': 1176, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 24, 'dst_loc': 'HSK', 'dst_time': 1176, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 20, 'dst_loc': 'ATB', 'dst_time': 1188, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 25, 'dst_loc': 'HSK', 'dst_time': 1188, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 26, 'dst_loc': 'ATB', 'dst_time': 1200, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 30, 'dst_loc': 'HSK', 'dst_time': 1200, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 27, 'dst_loc': 'ATB', 'dst_time': 1215, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 31, 'dst_loc': 'HSK', 'dst_time': 1215, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 28, 'dst_loc': 'ATB', 'dst_time': 1230, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 32, 'dst_loc': 'HSK', 'dst_time': 1230, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 29, 'dst_loc': 'ATB', 'dst_time': 1245, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 33, 'dst_loc': 'HSK', 'dst_time': 1245, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 34, 'dst_loc': 'ATB', 'dst_time': 1260, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 39, 'dst_loc': 'HSK', 'dst_time': 1260, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 35, 'dst_loc': 'ATB', 'dst_time': 1272, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 40, 'dst_loc': 'HSK', 'dst_time': 1272, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 36, 'dst_loc': 'ATB', 'dst_time': 1284, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 41, 'dst_loc': 'HSK', 'dst_time': 1284, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 37, 'dst_loc': 'ATB', 'dst_time': 1296, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 42, 'dst_loc': 'HSK', 'dst_time': 1296, 'cost': 10, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 38, 'dst_loc': 'ATB', 'dst_time': 1308, 'cost': 40, 'N_bus': 150}
# {'src_id': 1, 'src_loc': 'X', 'src_time': 0, 'dst_id': 43, 'dst_loc': 'HSK', 'dst_time': 1308, 'cost': 10, 'N_bus': 150}
# {'src_id': 2, 'src_loc': 'ATB', 'src_time': 1020, 'dst_id': 45, 'dst_loc': 'HSK', 'dst_time': 1130, 'cost': 110, 'N_bus': 1}
# {'src_id': 45, 'src_loc': 'HSK', 'src_time': 1130, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 5, 'src_loc': 'HSK', 'src_time': 1020, 'dst_id': 46, 'dst_loc': 'ATB', 'dst_time': 1130, 'cost': 110, 'N_bus': 1}
# {'src_id': 46, 'src_loc': 'ATB', 'src_time': 1130, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 3, 'src_loc': 'ATB', 'src_time': 1040, 'dst_id': 47, 'dst_loc': 'HSK', 'dst_time': 1150, 'cost': 110, 'N_bus': 1}
# {'src_id': 47, 'src_loc': 'HSK', 'src_time': 1150, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 6, 'src_loc': 'HSK', 'src_time': 1040, 'dst_id': 48, 'dst_loc': 'ATB', 'dst_time': 1150, 'cost': 110, 'N_bus': 1}
# {'src_id': 48, 'src_loc': 'ATB', 'src_time': 1150, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 4, 'src_loc': 'ATB', 'src_time': 1060, 'dst_id': 49, 'dst_loc': 'HSK', 'dst_time': 1170, 'cost': 110, 'N_bus': 1}
# {'src_id': 49, 'src_loc': 'HSK', 'src_time': 1170, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 7, 'src_loc': 'HSK', 'src_time': 1060, 'dst_id': 50, 'dst_loc': 'ATB', 'dst_time': 1170, 'cost': 110, 'N_bus': 1}
# {'src_id': 50, 'src_loc': 'ATB', 'src_time': 1170, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 8, 'src_loc': 'ATB', 'src_time': 1080, 'dst_id': 51, 'dst_loc': 'HSK', 'dst_time': 1190, 'cost': 110, 'N_bus': 1}
# {'src_id': 51, 'src_loc': 'HSK', 'src_time': 1190, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 12, 'src_loc': 'HSK', 'src_time': 1080, 'dst_id': 52, 'dst_loc': 'ATB', 'dst_time': 1190, 'cost': 110, 'N_bus': 1}
# {'src_id': 52, 'src_loc': 'ATB', 'src_time': 1190, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 9, 'src_loc': 'ATB', 'src_time': 1095, 'dst_id': 53, 'dst_loc': 'HSK', 'dst_time': 1205, 'cost': 110, 'N_bus': 1}
# {'src_id': 53, 'src_loc': 'HSK', 'src_time': 1205, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 13, 'src_loc': 'HSK', 'src_time': 1095, 'dst_id': 54, 'dst_loc': 'ATB', 'dst_time': 1205, 'cost': 110, 'N_bus': 1}
# {'src_id': 54, 'src_loc': 'ATB', 'src_time': 1205, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 10, 'src_loc': 'ATB', 'src_time': 1110, 'dst_id': 55, 'dst_loc': 'HSK', 'dst_time': 1220, 'cost': 110, 'N_bus': 1}
# {'src_id': 55, 'src_loc': 'HSK', 'src_time': 1220, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 14, 'src_loc': 'HSK', 'src_time': 1110, 'dst_id': 56, 'dst_loc': 'ATB', 'dst_time': 1220, 'cost': 110, 'N_bus': 1}
# {'src_id': 56, 'src_loc': 'ATB', 'src_time': 1220, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 11, 'src_loc': 'ATB', 'src_time': 1125, 'dst_id': 57, 'dst_loc': 'HSK', 'dst_time': 1235, 'cost': 110, 'N_bus': 1}
# {'src_id': 57, 'src_loc': 'HSK', 'src_time': 1235, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 15, 'src_loc': 'HSK', 'src_time': 1125, 'dst_id': 58, 'dst_loc': 'ATB', 'dst_time': 1235, 'cost': 110, 'N_bus': 1}
# {'src_id': 58, 'src_loc': 'ATB', 'src_time': 1235, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 16, 'src_loc': 'ATB', 'src_time': 1140, 'dst_id': 59, 'dst_loc': 'HSK', 'dst_time': 1250, 'cost': 110, 'N_bus': 1}
# {'src_id': 59, 'src_loc': 'HSK', 'src_time': 1250, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 21, 'src_loc': 'HSK', 'src_time': 1140, 'dst_id': 60, 'dst_loc': 'ATB', 'dst_time': 1250, 'cost': 110, 'N_bus': 1}
# {'src_id': 60, 'src_loc': 'ATB', 'src_time': 1250, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 17, 'src_loc': 'ATB', 'src_time': 1152, 'dst_id': 61, 'dst_loc': 'HSK', 'dst_time': 1262, 'cost': 110, 'N_bus': 1}
# {'src_id': 61, 'src_loc': 'HSK', 'src_time': 1262, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 22, 'src_loc': 'HSK', 'src_time': 1152, 'dst_id': 62, 'dst_loc': 'ATB', 'dst_time': 1262, 'cost': 110, 'N_bus': 1}
# {'src_id': 62, 'src_loc': 'ATB', 'src_time': 1262, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 18, 'src_loc': 'ATB', 'src_time': 1164, 'dst_id': 63, 'dst_loc': 'HSK', 'dst_time': 1274, 'cost': 110, 'N_bus': 1}
# {'src_id': 63, 'src_loc': 'HSK', 'src_time': 1274, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 23, 'src_loc': 'HSK', 'src_time': 1164, 'dst_id': 64, 'dst_loc': 'ATB', 'dst_time': 1274, 'cost': 110, 'N_bus': 1}
# {'src_id': 64, 'src_loc': 'ATB', 'src_time': 1274, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 19, 'src_loc': 'ATB', 'src_time': 1176, 'dst_id': 65, 'dst_loc': 'HSK', 'dst_time': 1286, 'cost': 110, 'N_bus': 1}
# {'src_id': 65, 'src_loc': 'HSK', 'src_time': 1286, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 24, 'src_loc': 'HSK', 'src_time': 1176, 'dst_id': 66, 'dst_loc': 'ATB', 'dst_time': 1286, 'cost': 110, 'N_bus': 1}
# {'src_id': 66, 'src_loc': 'ATB', 'src_time': 1286, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 20, 'src_loc': 'ATB', 'src_time': 1188, 'dst_id': 67, 'dst_loc': 'HSK', 'dst_time': 1298, 'cost': 110, 'N_bus': 1}
# {'src_id': 67, 'src_loc': 'HSK', 'src_time': 1298, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 25, 'src_loc': 'HSK', 'src_time': 1188, 'dst_id': 68, 'dst_loc': 'ATB', 'dst_time': 1298, 'cost': 110, 'N_bus': 1}
# {'src_id': 68, 'src_loc': 'ATB', 'src_time': 1298, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 26, 'src_loc': 'ATB', 'src_time': 1200, 'dst_id': 69, 'dst_loc': 'HSK', 'dst_time': 1310, 'cost': 110, 'N_bus': 1}
# {'src_id': 69, 'src_loc': 'HSK', 'src_time': 1310, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 30, 'src_loc': 'HSK', 'src_time': 1200, 'dst_id': 70, 'dst_loc': 'ATB', 'dst_time': 1310, 'cost': 110, 'N_bus': 1}
# {'src_id': 70, 'src_loc': 'ATB', 'src_time': 1310, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 27, 'src_loc': 'ATB', 'src_time': 1215, 'dst_id': 71, 'dst_loc': 'HSK', 'dst_time': 1325, 'cost': 110, 'N_bus': 1}
# {'src_id': 71, 'src_loc': 'HSK', 'src_time': 1325, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 31, 'src_loc': 'HSK', 'src_time': 1215, 'dst_id': 72, 'dst_loc': 'ATB', 'dst_time': 1325, 'cost': 110, 'N_bus': 1}
# {'src_id': 72, 'src_loc': 'ATB', 'src_time': 1325, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 28, 'src_loc': 'ATB', 'src_time': 1230, 'dst_id': 73, 'dst_loc': 'HSK', 'dst_time': 1340, 'cost': 110, 'N_bus': 1}
# {'src_id': 73, 'src_loc': 'HSK', 'src_time': 1340, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 32, 'src_loc': 'HSK', 'src_time': 1230, 'dst_id': 74, 'dst_loc': 'ATB', 'dst_time': 1340, 'cost': 110, 'N_bus': 1}
# {'src_id': 74, 'src_loc': 'ATB', 'src_time': 1340, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 29, 'src_loc': 'ATB', 'src_time': 1245, 'dst_id': 75, 'dst_loc': 'HSK', 'dst_time': 1355, 'cost': 110, 'N_bus': 1}
# {'src_id': 75, 'src_loc': 'HSK', 'src_time': 1355, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 33, 'src_loc': 'HSK', 'src_time': 1245, 'dst_id': 76, 'dst_loc': 'ATB', 'dst_time': 1355, 'cost': 110, 'N_bus': 1}
# {'src_id': 76, 'src_loc': 'ATB', 'src_time': 1355, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 34, 'src_loc': 'ATB', 'src_time': 1260, 'dst_id': 77, 'dst_loc': 'HSK', 'dst_time': 1370, 'cost': 110, 'N_bus': 1}
# {'src_id': 77, 'src_loc': 'HSK', 'src_time': 1370, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 39, 'src_loc': 'HSK', 'src_time': 1260, 'dst_id': 78, 'dst_loc': 'ATB', 'dst_time': 1370, 'cost': 110, 'N_bus': 1}
# {'src_id': 78, 'src_loc': 'ATB', 'src_time': 1370, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 35, 'src_loc': 'ATB', 'src_time': 1272, 'dst_id': 79, 'dst_loc': 'HSK', 'dst_time': 1382, 'cost': 110, 'N_bus': 1}
# {'src_id': 79, 'src_loc': 'HSK', 'src_time': 1382, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 40, 'src_loc': 'HSK', 'src_time': 1272, 'dst_id': 80, 'dst_loc': 'ATB', 'dst_time': 1382, 'cost': 110, 'N_bus': 1}
# {'src_id': 80, 'src_loc': 'ATB', 'src_time': 1382, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 36, 'src_loc': 'ATB', 'src_time': 1284, 'dst_id': 81, 'dst_loc': 'HSK', 'dst_time': 1394, 'cost': 110, 'N_bus': 1}
# {'src_id': 81, 'src_loc': 'HSK', 'src_time': 1394, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 41, 'src_loc': 'HSK', 'src_time': 1284, 'dst_id': 82, 'dst_loc': 'ATB', 'dst_time': 1394, 'cost': 110, 'N_bus': 1}
# {'src_id': 82, 'src_loc': 'ATB', 'src_time': 1394, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 37, 'src_loc': 'ATB', 'src_time': 1296, 'dst_id': 83, 'dst_loc': 'HSK', 'dst_time': 1406, 'cost': 110, 'N_bus': 1}
# {'src_id': 83, 'src_loc': 'HSK', 'src_time': 1406, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 42, 'src_loc': 'HSK', 'src_time': 1296, 'dst_id': 84, 'dst_loc': 'ATB', 'dst_time': 1406, 'cost': 110, 'N_bus': 1}
# {'src_id': 84, 'src_loc': 'ATB', 'src_time': 1406, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 38, 'src_loc': 'ATB', 'src_time': 1308, 'dst_id': 85, 'dst_loc': 'HSK', 'dst_time': 1418, 'cost': 110, 'N_bus': 1}
# {'src_id': 85, 'src_loc': 'HSK', 'src_time': 1418, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 10, 'N_bus': 150}
# {'src_id': 43, 'src_loc': 'HSK', 'src_time': 1308, 'dst_id': 86, 'dst_loc': 'ATB', 'dst_time': 1418, 'cost': 110, 'N_bus': 1}
# {'src_id': 86, 'src_loc': 'ATB', 'src_time': 1418, 'dst_id': 44, 'dst_loc': 'X', 'dst_time': 1440, 'cost': 40, 'N_bus': 150}
# {'src_id': 2, 'src_loc': 'ATB', 'src_time': 1020, 'dst_id': 3, 'dst_loc': 'ATB', 'dst_time': 1040, 'cost': 200, 'N_bus': 150}
# {'src_id': 3, 'src_loc': 'ATB', 'src_time': 1040, 'dst_id': 4, 'dst_loc': 'ATB', 'dst_time': 1060, 'cost': 200, 'N_bus': 150}
# {'src_id': 4, 'src_loc': 'ATB', 'src_time': 1060, 'dst_id': 8, 'dst_loc': 'ATB', 'dst_time': 1080, 'cost': 200, 'N_bus': 150}
# {'src_id': 8, 'src_loc': 'ATB', 'src_time': 1080, 'dst_id': 9, 'dst_loc': 'ATB', 'dst_time': 1095, 'cost': 200, 'N_bus': 150}
# {'src_id': 9, 'src_loc': 'ATB', 'src_time': 1095, 'dst_id': 10, 'dst_loc': 'ATB', 'dst_time': 1110, 'cost': 200, 'N_bus': 150}
# {'src_id': 10, 'src_loc': 'ATB', 'src_time': 1110, 'dst_id': 11, 'dst_loc': 'ATB', 'dst_time': 1125, 'cost': 200, 'N_bus': 150}
# {'src_id': 11, 'src_loc': 'ATB', 'src_time': 1125, 'dst_id': 46, 'dst_loc': 'ATB', 'dst_time': 1130, 'cost': 200, 'N_bus': 150}
# {'src_id': 46, 'src_loc': 'ATB', 'src_time': 1130, 'dst_id': 16, 'dst_loc': 'ATB', 'dst_time': 1140, 'cost': 200, 'N_bus': 150}
# {'src_id': 16, 'src_loc': 'ATB', 'src_time': 1140, 'dst_id': 48, 'dst_loc': 'ATB', 'dst_time': 1150, 'cost': 200, 'N_bus': 150}
# {'src_id': 48, 'src_loc': 'ATB', 'src_time': 1150, 'dst_id': 17, 'dst_loc': 'ATB', 'dst_time': 1152, 'cost': 200, 'N_bus': 150}
# {'src_id': 17, 'src_loc': 'ATB', 'src_time': 1152, 'dst_id': 18, 'dst_loc': 'ATB', 'dst_time': 1164, 'cost': 200, 'N_bus': 150}
# {'src_id': 18, 'src_loc': 'ATB', 'src_time': 1164, 'dst_id': 50, 'dst_loc': 'ATB', 'dst_time': 1170, 'cost': 200, 'N_bus': 150}
# {'src_id': 50, 'src_loc': 'ATB', 'src_time': 1170, 'dst_id': 19, 'dst_loc': 'ATB', 'dst_time': 1176, 'cost': 200, 'N_bus': 150}
# {'src_id': 19, 'src_loc': 'ATB', 'src_time': 1176, 'dst_id': 20, 'dst_loc': 'ATB', 'dst_time': 1188, 'cost': 200, 'N_bus': 150}
# {'src_id': 20, 'src_loc': 'ATB', 'src_time': 1188, 'dst_id': 52, 'dst_loc': 'ATB', 'dst_time': 1190, 'cost': 200, 'N_bus': 150}
# {'src_id': 52, 'src_loc': 'ATB', 'src_time': 1190, 'dst_id': 26, 'dst_loc': 'ATB', 'dst_time': 1200, 'cost': 200, 'N_bus': 150}
# {'src_id': 26, 'src_loc': 'ATB', 'src_time': 1200, 'dst_id': 54, 'dst_loc': 'ATB', 'dst_time': 1205, 'cost': 200, 'N_bus': 150}
# {'src_id': 54, 'src_loc': 'ATB', 'src_time': 1205, 'dst_id': 27, 'dst_loc': 'ATB', 'dst_time': 1215, 'cost': 200, 'N_bus': 150}
# {'src_id': 27, 'src_loc': 'ATB', 'src_time': 1215, 'dst_id': 56, 'dst_loc': 'ATB', 'dst_time': 1220, 'cost': 200, 'N_bus': 150}
# {'src_id': 56, 'src_loc': 'ATB', 'src_time': 1220, 'dst_id': 28, 'dst_loc': 'ATB', 'dst_time': 1230, 'cost': 200, 'N_bus': 150}
# {'src_id': 28, 'src_loc': 'ATB', 'src_time': 1230, 'dst_id': 58, 'dst_loc': 'ATB', 'dst_time': 1235, 'cost': 200, 'N_bus': 150}
# {'src_id': 58, 'src_loc': 'ATB', 'src_time': 1235, 'dst_id': 29, 'dst_loc': 'ATB', 'dst_time': 1245, 'cost': 200, 'N_bus': 150}
# {'src_id': 29, 'src_loc': 'ATB', 'src_time': 1245, 'dst_id': 60, 'dst_loc': 'ATB', 'dst_time': 1250, 'cost': 200, 'N_bus': 150}
# {'src_id': 60, 'src_loc': 'ATB', 'src_time': 1250, 'dst_id': 34, 'dst_loc': 'ATB', 'dst_time': 1260, 'cost': 200, 'N_bus': 150}
# {'src_id': 34, 'src_loc': 'ATB', 'src_time': 1260, 'dst_id': 62, 'dst_loc': 'ATB', 'dst_time': 1262, 'cost': 200, 'N_bus': 150}
# {'src_id': 62, 'src_loc': 'ATB', 'src_time': 1262, 'dst_id': 35, 'dst_loc': 'ATB', 'dst_time': 1272, 'cost': 200, 'N_bus': 150}
# {'src_id': 35, 'src_loc': 'ATB', 'src_time': 1272, 'dst_id': 64, 'dst_loc': 'ATB', 'dst_time': 1274, 'cost': 200, 'N_bus': 150}
# {'src_id': 64, 'src_loc': 'ATB', 'src_time': 1274, 'dst_id': 36, 'dst_loc': 'ATB', 'dst_time': 1284, 'cost': 200, 'N_bus': 150}
# {'src_id': 36, 'src_loc': 'ATB', 'src_time': 1284, 'dst_id': 66, 'dst_loc': 'ATB', 'dst_time': 1286, 'cost': 200, 'N_bus': 150}
# {'src_id': 66, 'src_loc': 'ATB', 'src_time': 1286, 'dst_id': 37, 'dst_loc': 'ATB', 'dst_time': 1296, 'cost': 200, 'N_bus': 150}
# {'src_id': 37, 'src_loc': 'ATB', 'src_time': 1296, 'dst_id': 68, 'dst_loc': 'ATB', 'dst_time': 1298, 'cost': 200, 'N_bus': 150}
# {'src_id': 68, 'src_loc': 'ATB', 'src_time': 1298, 'dst_id': 38, 'dst_loc': 'ATB', 'dst_time': 1308, 'cost': 200, 'N_bus': 150}
# {'src_id': 38, 'src_loc': 'ATB', 'src_time': 1308, 'dst_id': 70, 'dst_loc': 'ATB', 'dst_time': 1310, 'cost': 200, 'N_bus': 150}
# {'src_id': 70, 'src_loc': 'ATB', 'src_time': 1310, 'dst_id': 72, 'dst_loc': 'ATB', 'dst_time': 1325, 'cost': 200, 'N_bus': 150}
# {'src_id': 72, 'src_loc': 'ATB', 'src_time': 1325, 'dst_id': 74, 'dst_loc': 'ATB', 'dst_time': 1340, 'cost': 200, 'N_bus': 150}
# {'src_id': 74, 'src_loc': 'ATB', 'src_time': 1340, 'dst_id': 76, 'dst_loc': 'ATB', 'dst_time': 1355, 'cost': 200, 'N_bus': 150}
# {'src_id': 76, 'src_loc': 'ATB', 'src_time': 1355, 'dst_id': 78, 'dst_loc': 'ATB', 'dst_time': 1370, 'cost': 200, 'N_bus': 150}
# {'src_id': 78, 'src_loc': 'ATB', 'src_time': 1370, 'dst_id': 80, 'dst_loc': 'ATB', 'dst_time': 1382, 'cost': 200, 'N_bus': 150}
# {'src_id': 80, 'src_loc': 'ATB', 'src_time': 1382, 'dst_id': 82, 'dst_loc': 'ATB', 'dst_time': 1394, 'cost': 200, 'N_bus': 150}
# {'src_id': 82, 'src_loc': 'ATB', 'src_time': 1394, 'dst_id': 84, 'dst_loc': 'ATB', 'dst_time': 1406, 'cost': 200, 'N_bus': 150}
# {'src_id': 84, 'src_loc': 'ATB', 'src_time': 1406, 'dst_id': 86, 'dst_loc': 'ATB', 'dst_time': 1418, 'cost': 200, 'N_bus': 150}
# {'src_id': 5, 'src_loc': 'HSK', 'src_time': 1020, 'dst_id': 6, 'dst_loc': 'HSK', 'dst_time': 1040, 'cost': 200, 'N_bus': 150}
# {'src_id': 6, 'src_loc': 'HSK', 'src_time': 1040, 'dst_id': 7, 'dst_loc': 'HSK', 'dst_time': 1060, 'cost': 200, 'N_bus': 150}
# {'src_id': 7, 'src_loc': 'HSK', 'src_time': 1060, 'dst_id': 12, 'dst_loc': 'HSK', 'dst_time': 1080, 'cost': 200, 'N_bus': 150}
# {'src_id': 12, 'src_loc': 'HSK', 'src_time': 1080, 'dst_id': 13, 'dst_loc': 'HSK', 'dst_time': 1095, 'cost': 200, 'N_bus': 150}
# {'src_id': 13, 'src_loc': 'HSK', 'src_time': 1095, 'dst_id': 14, 'dst_loc': 'HSK', 'dst_time': 1110, 'cost': 200, 'N_bus': 150}
# {'src_id': 14, 'src_loc': 'HSK', 'src_time': 1110, 'dst_id': 15, 'dst_loc': 'HSK', 'dst_time': 1125, 'cost': 200, 'N_bus': 150}
# {'src_id': 15, 'src_loc': 'HSK', 'src_time': 1125, 'dst_id': 45, 'dst_loc': 'HSK', 'dst_time': 1130, 'cost': 200, 'N_bus': 150}
# {'src_id': 45, 'src_loc': 'HSK', 'src_time': 1130, 'dst_id': 21, 'dst_loc': 'HSK', 'dst_time': 1140, 'cost': 200, 'N_bus': 150}
# {'src_id': 21, 'src_loc': 'HSK', 'src_time': 1140, 'dst_id': 47, 'dst_loc': 'HSK', 'dst_time': 1150, 'cost': 200, 'N_bus': 150}
# {'src_id': 47, 'src_loc': 'HSK', 'src_time': 1150, 'dst_id': 22, 'dst_loc': 'HSK', 'dst_time': 1152, 'cost': 200, 'N_bus': 150}
# {'src_id': 22, 'src_loc': 'HSK', 'src_time': 1152, 'dst_id': 23, 'dst_loc': 'HSK', 'dst_time': 1164, 'cost': 200, 'N_bus': 150}
# {'src_id': 23, 'src_loc': 'HSK', 'src_time': 1164, 'dst_id': 49, 'dst_loc': 'HSK', 'dst_time': 1170, 'cost': 200, 'N_bus': 150}
# {'src_id': 49, 'src_loc': 'HSK', 'src_time': 1170, 'dst_id': 24, 'dst_loc': 'HSK', 'dst_time': 1176, 'cost': 200, 'N_bus': 150}
# {'src_id': 24, 'src_loc': 'HSK', 'src_time': 1176, 'dst_id': 25, 'dst_loc': 'HSK', 'dst_time': 1188, 'cost': 200, 'N_bus': 150}
# {'src_id': 25, 'src_loc': 'HSK', 'src_time': 1188, 'dst_id': 51, 'dst_loc': 'HSK', 'dst_time': 1190, 'cost': 200, 'N_bus': 150}
# {'src_id': 51, 'src_loc': 'HSK', 'src_time': 1190, 'dst_id': 30, 'dst_loc': 'HSK', 'dst_time': 1200, 'cost': 200, 'N_bus': 150}
# {'src_id': 30, 'src_loc': 'HSK', 'src_time': 1200, 'dst_id': 53, 'dst_loc': 'HSK', 'dst_time': 1205, 'cost': 200, 'N_bus': 150}
# {'src_id': 53, 'src_loc': 'HSK', 'src_time': 1205, 'dst_id': 31, 'dst_loc': 'HSK', 'dst_time': 1215, 'cost': 200, 'N_bus': 150}
# {'src_id': 31, 'src_loc': 'HSK', 'src_time': 1215, 'dst_id': 55, 'dst_loc': 'HSK', 'dst_time': 1220, 'cost': 200, 'N_bus': 150}
# {'src_id': 55, 'src_loc': 'HSK', 'src_time': 1220, 'dst_id': 32, 'dst_loc': 'HSK', 'dst_time': 1230, 'cost': 200, 'N_bus': 150}
# {'src_id': 32, 'src_loc': 'HSK', 'src_time': 1230, 'dst_id': 57, 'dst_loc': 'HSK', 'dst_time': 1235, 'cost': 200, 'N_bus': 150}
# {'src_id': 57, 'src_loc': 'HSK', 'src_time': 1235, 'dst_id': 33, 'dst_loc': 'HSK', 'dst_time': 1245, 'cost': 200, 'N_bus': 150}
# {'src_id': 33, 'src_loc': 'HSK', 'src_time': 1245, 'dst_id': 59, 'dst_loc': 'HSK', 'dst_time': 1250, 'cost': 200, 'N_bus': 150}
# {'src_id': 59, 'src_loc': 'HSK', 'src_time': 1250, 'dst_id': 39, 'dst_loc': 'HSK', 'dst_time': 1260, 'cost': 200, 'N_bus': 150}
# {'src_id': 39, 'src_loc': 'HSK', 'src_time': 1260, 'dst_id': 61, 'dst_loc': 'HSK', 'dst_time': 1262, 'cost': 200, 'N_bus': 150}
# {'src_id': 61, 'src_loc': 'HSK', 'src_time': 1262, 'dst_id': 40, 'dst_loc': 'HSK', 'dst_time': 1272, 'cost': 200, 'N_bus': 150}
# {'src_id': 40, 'src_loc': 'HSK', 'src_time': 1272, 'dst_id': 63, 'dst_loc': 'HSK', 'dst_time': 1274, 'cost': 200, 'N_bus': 150}
# {'src_id': 63, 'src_loc': 'HSK', 'src_time': 1274, 'dst_id': 41, 'dst_loc': 'HSK', 'dst_time': 1284, 'cost': 200, 'N_bus': 150}
# {'src_id': 41, 'src_loc': 'HSK', 'src_time': 1284, 'dst_id': 65, 'dst_loc': 'HSK', 'dst_time': 1286, 'cost': 200, 'N_bus': 150}
# {'src_id': 65, 'src_loc': 'HSK', 'src_time': 1286, 'dst_id': 42, 'dst_loc': 'HSK', 'dst_time': 1296, 'cost': 200, 'N_bus': 150}
# {'src_id': 42, 'src_loc': 'HSK', 'src_time': 1296, 'dst_id': 67, 'dst_loc': 'HSK', 'dst_time': 1298, 'cost': 200, 'N_bus': 150}
# {'src_id': 67, 'src_loc': 'HSK', 'src_time': 1298, 'dst_id': 43, 'dst_loc': 'HSK', 'dst_time': 1308, 'cost': 200, 'N_bus': 150}
# {'src_id': 43, 'src_loc': 'HSK', 'src_time': 1308, 'dst_id': 69, 'dst_loc': 'HSK', 'dst_time': 1310, 'cost': 200, 'N_bus': 150}
# {'src_id': 69, 'src_loc': 'HSK', 'src_time': 1310, 'dst_id': 71, 'dst_loc': 'HSK', 'dst_time': 1325, 'cost': 200, 'N_bus': 150}
# {'src_id': 71, 'src_loc': 'HSK', 'src_time': 1325, 'dst_id': 73, 'dst_loc': 'HSK', 'dst_time': 1340, 'cost': 200, 'N_bus': 150}
# {'src_id': 73, 'src_loc': 'HSK', 'src_time': 1340, 'dst_id': 75, 'dst_loc': 'HSK', 'dst_time': 1355, 'cost': 200, 'N_bus': 150}
# {'src_id': 75, 'src_loc': 'HSK', 'src_time': 1355, 'dst_id': 77, 'dst_loc': 'HSK', 'dst_time': 1370, 'cost': 200, 'N_bus': 150}
# {'src_id': 77, 'src_loc': 'HSK', 'src_time': 1370, 'dst_id': 79, 'dst_loc': 'HSK', 'dst_time': 1382, 'cost': 200, 'N_bus': 150}
# {'src_id': 79, 'src_loc': 'HSK', 'src_time': 1382, 'dst_id': 81, 'dst_loc': 'HSK', 'dst_time': 1394, 'cost': 200, 'N_bus': 150}
# {'src_id': 81, 'src_loc': 'HSK', 'src_time': 1394, 'dst_id': 83, 'dst_loc': 'HSK', 'dst_time': 1406, 'cost': 200, 'N_bus': 150}
# {'src_id': 83, 'src_loc': 'HSK', 'src_time': 1406, 'dst_id': 85, 'dst_loc': 'HSK', 'dst_time': 1418, 'cost': 200, 'N_bus': 150}
# {'src_id': 2, 'src_loc': 'ATB', 'src_time': 1020, 'dst_id': 21, 'dst_loc': 'HSK', 'dst_time': 1140, 'cost': 180, 'N_bus': 150}
# {'src_id': 5, 'src_loc': 'HSK', 'src_time': 1020, 'dst_id': 16, 'dst_loc': 'ATB', 'dst_time': 1140, 'cost': 180, 'N_bus': 150}
# {'src_id': 3, 'src_loc': 'ATB', 'src_time': 1040, 'dst_id': 22, 'dst_loc': 'HSK', 'dst_time': 1152, 'cost': 180, 'N_bus': 150}
# {'src_id': 6, 'src_loc': 'HSK', 'src_time': 1040, 'dst_id': 17, 'dst_loc': 'ATB', 'dst_time': 1152, 'cost':
 'N_bus': 150}
# {'src_id': 68, 'src_loc': 'ATB', 'src_time': 1298, 'dst_id': 85, 'dst_loc': 'HSK', 'dst_time': 1418, 'cost': 180, 'N_bus': 150}
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_LPMethod                                3
# Tried aggregator 1 time.
# MIP Presolve eliminated 188 rows and 48 columns.
# MIP Presolve modified 151650 coefficients.
# Reduced MIP has 95752 rows, 54300 columns, and 367200 nonzeros.
# Reduced MIP has 41250 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 1.01 sec. (504.33 ticks)
# Probing fixed 1200 vars, tightened 0 bounds.
# Probing time = 4.92 sec. (44.49 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated 1800 rows and 1200 columns.
# MIP Presolve modified 1200 coefficients.
# Reduced MIP has 93952 rows, 53100 columns, and 358200 nonzeros.
# Reduced MIP has 40050 binaries, 150 generals, 0 SOSs, and 0 indicators.
# Presolve time = 1.08 sec. (399.41 ticks)
# Probing time = 0.47 sec. (22.62 ticks)
# Clique table members: 225184.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 32 threads.
# Root relaxation solution time = 1.41 sec. (508.48 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0    28320.0000   175                  28320.0000        9
# *     0+    0                        28320.0000    28320.0000             0.00%
#       0     0        cutoff          28320.0000    28320.0000        9    0.00%
# Elapsed time = 12.17 sec. (2297.09 ticks, tree = 0.01 MB, solutions = 1)
#
# Root node processing (before b&c):
#   Real time             =   12.20 sec. (2300.55 ticks)
# Parallel b&c, 32 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =   12.20 sec. (2300.55 ticks)
# Objective: 28320.0
# Number of vehicles used: 18
#
# Schedule for Vehicle 5: Utilization time = 220.00
#   (X at 00:00) --> (HSK at 18:30), cost=10
#   (HSK at 18:30) --> (ATB at 20:20), cost=110
#   (ATB at 20:20) --> (ATB at 20:30), cost=200
#   (ATB at 20:30) --> (HSK at 22:20), cost=110
#   (HSK at 22:20) --> (X at 24:00), cost=10
#
# Schedule for Vehicle 12: Utilization time = 220.00
#   (X at 00:00) --> (HSK at 18:45), cost=10
#   (HSK at 18:45) --> (ATB at 20:35), cost=110
#   (ATB at 20:35) --> (ATB at 20:45), cost=200
#   (ATB at 20:45) --> (HSK at 22:35), cost=110
#   (HSK at 22:35) --> (X at 24:00), cost=10
#
# Schedule for Vehicle 21: Utilization time = 220.00
#   (X at 00:00) --> (HSK at 19:24), cost=10
#   (HSK at 19:24) --> (ATB at 21:14), cost=110
#   (ATB at 21:14) --> (ATB at 21:24), cost=200
#   (ATB at 21:24) --> (HSK at 23:14), cost=110
#   (HSK at 23:14) --> (X at 24:00), cost=10
#
# Schedule for Vehicle 22: Utilization time = 330.00
#   (X at 00:00) --> (ATB at 17:40), cost=40
#   (ATB at 17:40) --> (HSK at 19:30), cost=110
#   (HSK at 19:30) --> (HSK at 19:36), cost=200
#   (HSK at 19:36) --> (ATB at 21:26), cost=110
#   (ATB at 21:26) --> (ATB at 21:36), cost=200
#   (ATB at 21:36) --> (HSK at 23:26), cost=110
#   (HSK at 23:26) --> (X at 24:00), cost=10
#
# Schedule for Vehicle 23: Utilization time = 220.00
#   (X at 00:00) --> (ATB at 18:15), cost=40
#   (ATB at 18:15) --> (HSK at 20:05), cost=110
#   (HSK at 20:05) --> (HSK at 20:15), cost=200
#   (HSK at 20:15) --> (ATB at 22:05), cost=110
#   (ATB at 22:05) --> (X at 24:00), cost=40
#
# Schedule for Vehicle 46: Utilization time = 220.00
#   (X at 00:00) --> (ATB at 19:48), cost=40
#   (ATB at 19:48) --> (HSK at 21:38), cost=110
#   (HSK at 21:38) --> (HSK at 21:48), cost=200
#   (HSK at 21:48) --> (ATB at 23:38), cost=110
#   (ATB at 23:38) --> (X at 24:00), cost=40
#
# Schedule for Vehicle 49: Utilization time = 220.00
#   (X at 00:00) --> (ATB at 18:00), cost=40
#   (ATB at 18:00) --> (HSK at 19:50), cost=110
#   (HSK at 19:50) --> (HSK at 20:00), cost=200
#   (HSK at 20:00) --> (ATB at 21:50), cost=110
#   (ATB at 21:50) --> (X at 24:00), cost=40
#
# Schedule for Vehicle 52: Utilization time = 330.00
#   (X at 00:00) --> (HSK at